# desired output is not obtained when certain input
# values are given. These types of errors which provide
# incorrect output but appears to be error-free are
# called
# 23/11/23, 11:43 am - Satyam Dimri: <Media omitted>
# 23/11/23, 2:39 pm - Satyam Dimri: bhej na
# 23/11/23, 2:39 pm - Satyam Dimri: phrasal verb
# 23/11/23, 2:40 pm - Satyam Kumar: <Media omitted>
# 23/11/23, 11:18 pm - Satyam Dimri: null
# 24/11/23, 12:11 am - Satyam Kumar: <Media omitted>
# 24/11/23, 12:12 am - Satyam Kumar: <Media omitted>
# 24/11/23, 9:45 pm - Satyam Kumar: Soham Ghosh.vcf (file attached)
# 27/11/23, 11:23 am - Satyam Kumar: Bro paise aaj daal dega mijhe apna ticket book karna tha
# 27/11/23, 11:45 am - Satyam Dimri: Maine bola to tha papa ko ..
# 27/11/23, 11:45 am - Satyam Dimri: Dubar bol dunga👍🏻
# 29/11/23, 12:02 pm - Satyam Dimri: <Media omitted>
# 29/11/23, 6:08 pm - Satyam Kumar: <Media omitted>
# 01/12/23, 1:07 am - Satyam Dimri: oye phy ke tutu ka sol bhejde jo tu dikha rha tha..
# 01/12/23, 1:07 am - Satyam Dimri: mere pass jo h vo alg h !!
# 02/12/23, 11:16 pm - Satyam Kumar: bol.'
# 03/12/23, 1:02 pm - Satyam Dimri: <Media omitted>
# 03/12/23, 1:11 pm - Satyam Kumar: #include <stdio.h>
#
# int i, j;
#
#
# //<<<<<<<<matrix display>>>>>>>>>>>
# void cmatrix(int c[3][3]) {
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             printf("%d\t", c[i][j]);
#         }
#         printf("\n");
#     }
# }
#
#
# //<<<<<<<<<<<<uppertriangularmatrix>>>>>>>>>>>
# void uptri(int matrix[3][3]) {
#     printf("Upper Triangular Matrix:\n");
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             if (i <= j) {
#                 printf("%d\t", matrix[i][j]);
#             } else {
#                 printf("0\t");
#             }
#         }
#         printf("\n");
#     }
# }
#
#
# //<<<<lower triangular matrix>>>>>>>>>>>>>>>>
# void lowtri(int matrix[3][3]) {
#     printf("Lower Triangular Matrix:\n");
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             if (i >= j) {
#                 printf("%d\t", matrix[i][j]);
#             } else {
#                 printf("0\t");
#             }
#         }
#         printf("\n");
#     }
# }
#
#
# //<<<<<<<<<transpose of matrix>>>>>>>>>>>>
# void transpose(int matrix[3][3]) {
#     printf("Transpose of Matrix:\n");
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             printf("%d\t", matrix[j][i]);
#         }
#         printf("\n");
#     }
# }
#
#
# //<<<<<<<<<check whether matrix is symmetric or not>>>>>>>>
# int isSymmetric(int matrix[3][3]) {
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             if (matrix[i][j] != matrix[j][i]) {
#                 return 0;
#             }
#         }
#     }
#     return 1;
# }
#
# //<<<<<<<<sum of diagonal>>>>>>>>>>>>>>>>>>>>>>>>
#
# int sumDiagonal(int matrix[3][3]) {
#     int sum = 0;
#     for (i = 0; i < 3; i++) {
#         sum += matrix[i][i];
#     }
#     return sum;
# }
#
#
# //<<<<<<<<add two matrix>>>>>>>>>>>>>>>>>>>>>>
# void addmatrix(int a[3][3], int b[3][3], int c[3][3]) {
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             c[i][j] = a[i][j] + b[i][j];
#         }
#     }
#     printf("Sum of matrices:\n");
#     cmatrix(c);
# }
#
#
#
#
#
#
# //<<<<<<<<substract two matrix>>>>>>>>>>>>>>>>>>>>>>
#
# void subsmatrix(int a[3][3], int b[3][3], int c[3][3]) {
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             c[i][j] = a[i][j] - b[i][j];
#         }
#     }
#     printf("Difference of matrices:\n");
#     cmatrix(c);
# }
#
# //<<<<<<<<add two matrix>>>>>>>>>>>>>>>>>>>>>>
#
# void mulmatrix(int a[3][3], int b[3][3], int c[3][3]) {
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             c[i][j] = 0;
#             for (int k = 0; k < 3; k++) {
#                 c[i][j] += a[i][k] * b[k][j];
#             }
#         }
#     }
#     printf("Product of matrices:\n");
#     cmatrix(c);
# }
#
# //<< find any element in 2d matrix>>>>>>>>>>>>
#
#
# void search(int a[3][3],int target) {
#     int found = 0;
#     for (i = 0; i <3; i++) {
#         for (j = 0; j <3; j++) {
#             if (a[i][j] == target) {
#                 printf("Element %d found at position (%d, %d)\n", target, i + 1, j + 1);
#                 found = 1;
#             }
#         }
#     }
#     if (!found) {
#         printf("Element %d not found in the matrix.\n", target);
#     }
# }
#
#
#
#
#
#
#
#
#
#
#
#
# int main() {
#
#     int num;
#     int matrix1[3][3];
#     int matrix2[3][3];
#     int matrixr[3][3];
#
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             printf("Enter %d,%d element of matrix 1: ", i + 1, j + 1);
#             scanf("%d", &matrix1[i][j]);
#         }
#         printf("\n");
#     }
#
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             printf("Enter %d,%d element of matrix 2: ", i + 1, j + 1);
#             scanf("%d", &matrix2[i][j]);
#         }
#         printf("\n");
#         printf(search(matrix1))
#     }
#
#     addmatrix(matrix1, matrix2, matrixr);
#     subsmatrix(matrix1, matrix2, matrixr);
#     mulmatrix(matrix1, matrix2, matrixr);
#
#     uptri(matrix1);
#     lowtri(matrix2);
#     transpose(matrix1);
#
#     int diagonalSum = sumDiagonal(matrix1);
#     printf("\nSum of diagonal elements of matrix A: %d\n", diagonalSum);
#
#     if (isSymmetric(matrix1)) {
#         printf("\nMatrix A is symmetric.\n");
#     } else {
#         printf("\nMatrix A is not symmetric.\n");
#     }
#
#     printf("Enter the target: ");
#
#
#     scanf("%d",&num);
#
#
#
#     search(matrix1,num);
#
#     return 0;
# }
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:05 pm - Satyam Kumar: A string in C is defined as an array of characters terminated by a null character ('\0').but An array of characters is a collection of individual characters stored in contiguous memory locations.
# 03/12/23, 11:07 pm - Satyam Dimri: contiguous memory locations?
# 03/12/23, 11:08 pm - Satyam Kumar: array of character ko 'a'; declare kaarenge to memory me 1 character lega but string "a" to memomry me 2 character lega ek 'a' aur dusra '\0'
# 03/12/23, 11:08 pm - Satyam Dimri: ok
# 03/12/23, 11:14 pm - Satyam Dimri: null
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Dimri: han ab khul rhe
# 03/12/23, 11:19 pm - Satyam Dimri: baki ke bhi bhej
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:22 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:23 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:23 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:23 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:23 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11
# 03/01/24, 4:13 pm - Satyam Dimri: null
# 03/01/24, 4:14 pm - Satyam Kumar: Train me hu aa rha hu 6 baje Tak
# 03/01/24, 6:19 pm - Satyam Dimri: #include<stdio.h>
# int main(){
#     int n;
#     int sum=0;
#     printf("enter n:");
#     scanf("%d",&n);
#     int arr[n];
#     for(int i=0;i<n;i++){
#         scanf("%d",&arr[i]);
#     }
#     for(int i=0;i<n;i++){
#         printf("%d",arr[i]);
#     }
#     for(int i=0;i<n;i++){
#         sum = sum+arr[i];
#     }
#     printf("%d",sum);
#     return 0;
# }
# 03/01/24, 6:19 pm - Satyam Dimri: ye sum ka code h .. ise pointers ke sath kaise likhu?
# 03/01/24, 6:21 pm - Satyam Dimri: ??
# 03/01/24, 6:22 pm - Satyam Kumar: #include <stdio.h>
#
# int main() {
#     int n;
#     int sum = 0;
#
#     printf("Enter n: ");
#     scanf("%d", &n);
#
#     int *arr = (int *)malloc(n * sizeof(int));
#
#     if (arr == NULL) {
#         printf("Memory allocation failed.\n");
#         return 1;
#     }
#
#     printf("Enter %d elements:\n", n);
#     for (int i = 0; i < n; i++) {
#         scanf("%d", arr + i);
#     }
#
#     printf("Entered elements: ");
#     for (int i = 0; i < n; i++) {
#         printf("%d ", *(arr + i));
#     }
#
#     for (int i = 0; i < n; i++) {
#         sum = sum + *(arr + i);
#     }
#
#     printf("\nSum: %d\n", sum);
#
#     free(arr);
#
#     return 0;
# }
# 03/01/24, 6:22 pm - Satyam Kumar: Dekh le jaha doubt ho puch lena
# 03/01/24, 6:22 pm - Satyam Dimri: ye chat gpt se kra h?
# 03/01/24, 6:22 pm - Satyam Kumar: Haa
# 03/01/24, 6:23 pm - Satyam Dimri: 🤦🏻‍♂️
# 03/01/24, 6:23 pm - Satyam Dimri: tu bta bhaii
# 03/01/24, 6:23 pm - Satyam Dimri: mere hi code me changes krke bta
# 03/01/24, 6:23 pm - Satyam Kumar: Abe laptop on karna padega ruk
# 03/01/24, 6:23 pm - Satyam Dimri: hn kr
# 03/01/24, 6:25 pm - Satyam Kumar: #include <stdio.h>
#
# int main() {
#     int n;
#     int sum = 0;
#
#     printf("Enter n: ");
#     scanf("%d", &n);
#
#     int arr[n];
#
#
#     int *ptr = arr;
#     for (int i = 0; i < n; i++) {
#         scanf("%d", ptr + i);
#     }
#
#     // Output using pointers
#     for (int i = 0; i < n; i++) {
#         printf("%d ", *(ptr + i));
#     }
#
#     // Sum using pointers
#     for (int i = 0; i < n; i++) {
#         sum += *(ptr + i);
#     }
#
#     printf("\nSum: %d", sum);
#
#     return 0;
# }
# 03/01/24, 6:25 pm - Satyam Kumar: le
# 03/01/24, 6:26 pm - Satyam Kumar: int *ptr = arr kaa mtlb hai arr ka first element ka address *ptr me store ho gya
# 03/01/24, 6:28 pm - Satyam Dimri: acha
# 03/01/24, 6:31 pm - Satyam Dimri: <Media omitted>
# 03/01/24, 6:47 pm - Satyam Kumar: Kyuki to sf me likha wo address jisme I add ho rha aur pf wala normal int hai
# 03/01/24, 10:40 pm - Satyam Dimri: WAP to check given word is present in a string or not iska code bataio
# 04/01/24, 6:43 pm - Satyam Dimri: <Media omitted>
# 04/01/24, 6:43 pm - Satyam Dimri: null
# 06/01/24, 9:30 am - Satyam Dimri: <Media omitted>
# 06/01/24, 6:04 pm - Satyam Dimri: Palindrome ka code bhejde short and simple sa
# 09/01/24, 12:57 am - Satyam Dimri: <Media omitted>
# 09/01/24, 12
# 15/02/24, 12:29 am - Satyam Kumar: <Media omitted>
# 15/02/24, 12:29 am - Satyam Kumar: <Media omitted>
# 15/02/24, 12:29 am - Satyam Kumar: <Media omitted>
# 15/02/24, 2:33 am - Satyam Dimri: 🫂
# 16/02/24, 12:49 am - Satyam Dimri: liklh lia
# ?
# 16/02/24, 12:50 am - Satyam Kumar: <Media omitted>
# 16/02/24, 12:55 am - Satyam Dimri: tune ni likha?
# 16/02/24, 12:55 am - Satyam Dimri: null
# 16/02/24, 1:20 pm - Satyam Dimri: <Media omitted>
# 16/02/24, 1:20 pm - Satyam Dimri: <Media omitted>
# 16/02/24, 5:47 pm - Satyam Dimri: profile credits kon dega?😂
# 16/02/24, 5:51 pm - Satyam Kumar: Mil jayega
# 16/02/24, 9:04 pm - Satyam Dimri: Us img ke corner me likhde .. clicked by satyam dimri🙃
# 17/02/24, 12:10 am - Satyam Dimri: oye sun !!
# 17/02/24, 12:11 am - Satyam Dimri: padding or greedy alignment kya hota h ?
# 17/02/24, 12:13 am - Satyam Dimri: null
# 17/02/24, 10:35 pm - Satyam Kumar: Photo bhej de
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 17/02/24, 10:48 pm - Satyam Dimri: <Media omitted>
# 20/02/24, 7:28 pm - Satyam Dimri: oye sun
# 20/02/24, 7:29 pm - Satyam Kumar: Bol
# 20/02/24, 7:31 pm - Satyam Dimri: merko oops ke topic wise questions practice krne h.. kaha se kru?
# 20/02/24, 7:32 pm - Satyam Kumar: Lab karle n
# 20/02/24, 7:32 pm - Satyam Kumar: Aur tute
# 20/02/24, 7:33 pm - Satyam Dimri: acha
# 21/02/24, 7:48 pm - Satyam Dimri: null
# 21/02/24, 11:04 pm - Satyam Kumar: https://open.spotify.com/track/4NmUWS9nRYY33CoInUlgB9?si=cJx55KD6Q9asSatmbhGV5A
# 22/02/24, 12:03 am - Satyam Dimri: null
# 22/02/24, 12:06 am - Satyam Kumar: <Media omitted>
# 22/02/24, 12:06 am - Satyam Kumar: <Media omitted>
# 22/02/24, 12:06 am - Satyam Kumar: <Media omitted>
# 22/02/24, 12:06 am - Satyam Kumar: <Media omitted>
# 22/02/24, 12:06 am - Satyam Kumar: <Media omitted>
# 22/02/24, 12:06 am - Satyam Kumar: <Media omitted>
# 22/02/24, 12:06 am - Satyam Kumar: <Media omitted>
# ...
#         word++;
#
#         c++;
#     }
#
#     cout << "Number of lines in file: " << lineCount << endl;
#     cout << "Number of words in file: " << word << endl;
#     cout<<"Number of characters: "<<c<<endl;
#     inputFile.close();
#     return 0;
#
#
#
#
#
#
# }
# 09/05/24, 10:37 pm - Satyam Dimri: 1st qn h ye?
# 09/05/24, 10:37 pm - Satyam Kumar: ni
# 09/05/24, 10:37 pm - Satyam Dimri: 2nd?
# 09/05/24, 10:37 pm - Satyam Kumar: haa bsdk
# 09/05/24, 10:38 pm - Satyam Dimri: bkl gali kyu de rha h
# 09/05/24, 10:38 pm - Satyam Kumar: bsdk tu hai kyuki
# 09/05/24, 10:38 pm - Satyam Kumar: bkl
# 09/05/24, 10:38 pm - Satyam Dimri: nhi ho rha bhaii abhi bhi vo
# 09/05/24, 10:39 pm - Satyam Kumar: Rehne de fir
# 09/05/24, 10:39 pm - Satyam Dimri: a rha hu tere pass
# 09/05/24, 10:56 pm - Satyam Kumar: #include <iostream>
# #include <fstream>
# using namespace std;
# int d=0;
# int main()
# {
#     bool cond = true;
#     do
#     {
#         cout << "Welcome to file encryption system:\n";
#         cout << "1. Display source file\n";
#         cout << "2. Encrypt source file \n";
#         cout << "3. Decrypt source file\n";
#         cout << "4. Quit\n";
#         int input;
#         cin>> input;
#         switch(input)
#         {
#             case 1:
#             {
#                 if(d!=1)
#                 {
#                     ofstream fout;
#                     fout.open("source.txt");
#                     if(!fout.good())
#                     {
#                         cout<<"Error in opening file"<<endl;
#                         return 1;
#                     }
#                     cout<<"Enter the text to write in file: "<<endl;
#                     cout<<"Enter -1 to stop"<<endl;
#                     string line;
#                     while(getline(cin,line) && line != "-1")
#                     {
#                         fout << line << endl;
#                     }
#
#                     fout.close();
#                     d=1;
#                 }
#                 ifstream fin;
#                 fin.open("source.txt");
#                 if(!fin.good())
#                 {
#                     cout<<"Error in opening file"<<endl;
#                     return 1;
#                 }
#
#                 cout<<"The content of source file is: "<<endl;
#                 string line1;
#                 while(getline(fin,line1))
#                 {
#                     cout<<line1<<endl;
#                 }
#                 fin.close();
#                 break;
#             }
#
#             case 2:
#             {
#                 ifstream fin("source.txt");
#                 if(!fin.good())
#                 {
#                     cout<<"Error in opening file"<<endl;
#                     return 1;
#                 }
#                 int key;
#                 cout<<"Enter key value to encrypt the file: ";
#                 cin>>key;
#                 ofstream fout;
#                 fout.open("encrypt.txt");
#                 if(!fout.good())
#                 {
#                     cout<<"Error in opening file"<<endl;
#                     return 1;
#                 }
#                 char ch;
#                 while(fin.get(ch))
#                 {
#                     ch += key;
#                     fout<<ch;
#                 }
#                 cout<<"File encrypted successfully"<<endl;
#                 fin.close();
#                 fout.close();
#                 break;
#             }
#
#             case 3:
#             {
#                 ifstream fin("encrypt.txt");
#                 if(!fin.good())
#                 {
#                     cout<<"Error in opening file"<<endl;
#                     return 1;
#                 }
#
#                 int key;
#                 cout<<"Enter key value to decrypt the file: ";
#                 cin>>key;
#
#                 ofstream fout("decrypt.txt");
#                 if(!fout.good())
#                 {
#                     cout<<"Error in opening file"<<endl;
#                     return 1;
#                 }
#
#                 char ch;
#                 while(fin.get(ch))
#                 {
#                     ch -= key;
#                     fout<<ch;
#                 }
#                 cout<<"File decrypted successfully"<<endl;
#                 fin.close();
#                 fout.close();
#                 break;
#
#             }
#
#             case 4:
#             {
#                 cout<<"Thank you for using file encryption system"<<endl;
#                 cond = false;
#                 break;
#             }
#
#             default:
#             {
#                 cout<<"Invalid input"<<endl;
#             }
#         }
#     } while (cond);
#
#     return 0;
# }
# 09/05/24, 10:58 pm - Satyam Kumar: #include <iostream>
# #include <fstream>
# using namespace std;
#
# int main()
# {
#     ofstream fout("test.txt");
#     ofstream fout1("test1.txt");
#     if(!fout.good())
#     {
#         cout<<"Error in creating file"<<endl;
#         return 1;
#     }
#     if(!fout1.good())
#     {
#         cout<<"Error in creating file"<<endl;
#         return 1;
#     }
#
#     fout<<1<<endl;
#     fout<<2<<endl;
#     fout<<3<<endl;
#     fout<<4<<endl;
#
#     fout1<<7<<endl;
#     fout1<<8<<endl;
#     fout1<<9<<endl;
#     fout1<<10<<endl;
#
#     fout.close();
#     fout1.close();
#
#     ifstream fin("test.txt");
#     ifstream fin1("test1.txt");
#     if(!fin.good())
#     {
#         cout<<"Error in opening file"<<endl;
#         return 1;
#     }
#     if(!fin1.good())
#     {
#         cout<<"Error in opening file"<<endl;
#         return 1;
#     }
#
#     ofstream out_file("Result.txt");
#     if(!out_file.good())
#     {
#         cout<<"Error in creating file"<<endl;
#         return 1;
#     }
#
#     int a;
#     int b;
#     fin>>a;
#     fin1>>b;
#
#     while(fin || fin1)
#     {
#         if(!fin)
#         {
#             out_file<<b<<endl;
#             fin1>>b;
#             continue;
#         }
#         else if(!fin1)
#         {
#             out_file<<a<<endl;
#             fin>>a;
#             continue;
#         }
#         if(a<b)
#         {
#             out_file<<a<<endl;
#             while(fin>>a && a<b)
#             {
#                 out_file<<a<<endl;
#             }
#         }
#         else if(b<a)
#         {
#             out_file<<b<<endl;
#             while(fin1>>b && b<a)
#             {
#                 out_file<<b<<endl;
#             }
#         }
#         else if(a==b)
#         {
#             out_file<<a<<endl<<b<<endl;
#         }
#
#     }
#
#     fin.close();
#     fin1.close();
#     out_file.close();
#
#     return 0;
# }
# 09/05/24, 11:02 pm - Satyam Dimri: 5 <This message was edited>
# 09/05/24, 11:03 pm - Satyam Kumar: #include <iostream>
# #include <fstream>
#
# using namespace std;
#
# int main()
# {
#     ofstream fin;
#     ofstream fin1;
#     fin.open("TEXT2.txt");
#     fin1.open("TEXT.txt");
#     if(!fin.good())
#     {
#         cout<<"Error in opening file"<<endl;
#         return 1;
#     }
#
#     if(!fin1.good())
#     {
#         cout<<"Error in opening file"<<endl;
#         return 1;
#     }
#
#     cout<<"Enter the text to write in file: "<<endl;
#     cout<<"Enter -1 to stop"<<endl;
#     string line;
#     while(getline(cin,line) && line != "-1")
#     {
#         fin << line << endl;
#     }
#
#     fin.close();
#
#     ifstream fout("TEXT2.txt");
#     if(!fout.good())
#     {
#         cout<<"Error in opening file"<<endl;
#         return 1;
#     }
#     cout<<"Copying the content of TEXT2.txt to TEXT.txt"<<endl;
#     string line1;
#     while(getline(fout,line1))
#     {
#         fin1 << line1 << endl;
#     }
#
#     fin1.close();
#     fout.close();
#     return 0;
#
#
# }
# 09/05/24, 11:03 pm - Satyam Dimri: 3
# 09/05/24, 11:03 pm - Satyam Kumar: #include <iostream>
# #include <fstream>
#
# using namespace std;
#
# int main()
# {
#     ofstream fout1("file1.txt");
#     if(!fout1.good())
#     {
#         cout<<"Error in opening file1"<<endl;
#     }
#
#     ofstream fout2("file2.txt");
#     if(!fout2.good())
#     {
#         cout<<"Error in opening file2"<<endl;
#     }
#
#     fout1<<"hi my name is ";
#     fout2<<"Avinash Sharma";
#
#     fout1.close();
#     fout2.close();
#
#     ofstream fout3("merge_file.txt");
#     if(!fout3.good())
#     {
#         cout<<"Error in opening merge_file"<<endl;
#         return 1;
#     }
#
#     ifstream fin1("file1.txt");
#     ifstream fin2("file2.txt");
#
#     string line;
#     if(fin1.good())
#     {
#         while(getline(fin1, line))
#         {
#             fout3 << line;
#         }
#     }
#     if(fin2.good())
#     {
#         while(getline(fin2, line))
#         {
#             fout3 << line ;
#         }
#     }
#
#     fin1.close();
#     fin2.close();
#     fout3.close();
n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Kal eng lab to nhi h na ?\n',
#  'Satyam Kumar: Photo bhej dena\n',
#  'Satyam Dimri: Ok\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: Oye sun\n',
#  'Satyam Kumar: Bol\n',
#  'Satyam Dimri: Cp ka tut krlia ?\n',
#  'Satyam Kumar: Cp ka lab kar rha\n',
#  'Satyam Dimri: bhejdio krke\n',
#  'Satyam Kumar: Ok\n',
#  'Satyam Dimri: or han sun ekbat or puchni thi...\n',
#  'Satyam Kumar: ?\n',
#  'Satyam Dimri: ye alamy pe login kaise krna h ?\n',
#  'Satyam Kumar: Adamy\n',
#  'Satyam Dimri: ha vhi\n',
#  'Satyam Kumar: App download karo\n',
#  'Satyam Dimri: laptop se nhi hoga?\n',
#  'Satyam Kumar: Nope\n',
#  'Satyam Dimri: acha ruk\n',
#  'Satyam Dimri: app ka link bhej\n',
#  'Satyam Kumar: https://play.google.com/store/apps/details?id=co.acetone.acadly\n',
#  'Satyam Dimri: thx\n',
#  'Satyam Dimri: bhaii lab file bhejde cp ki\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: bhej\n',
#  'Satyam Dimri: link\n',
#  'Satyam Kumar: https://www.youtube.com/playlist?list=PLbe3v70ubrmF0UlYR-8D9BdP7dLHUhpTN\n',
#  'Satyam Dimri: kaha tk pdhna h ?\n',
#  'Satyam Dimri: starting ki 3 vids?\n',
#  'Satyam Kumar: Upto 3 lec\n',
#  'Satyam Kumar: Yaa\n',
#  'Satyam Dimri: ok\n',
#  'Satyam Kumar: https://classroom.google.com/c/NjE4NzA3MjEyMTI2/m/NTIzNTQxNDUyODcw/details\n',
#  'Satyam Dimri: https://meet.google.com/mat-nkry-eob\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: same h dono\n',
#  'Satyam Kumar: Bhag be\n',
#  'Satyam Kumar: Same kaha hai\n',
#  'Satyam Dimri: 👍🏻thx\U0001fac2\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: If else vale ka ans bta\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: bro Saturday ko chalet hai aaj man nhi kar rha utna door jaane kaa\n',
#  'Satyam Dimri: Mai bhi nhi ja rha kal jayenge\n',
#  'Satyam Kumar: physics lab2 bhej de to\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: thanks\n',
#  'Satyam Dimri: Likh ke bhej dio ..\n',
#  'Satyam Dimri: likhne ke bad bhejdio\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: https://youtube.com/@DrMukeshChandraDimriPhysics?si=t3DggRlIRCuJefnp\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: 11 bje tk likh lega tu pura ?\n',
#  'Satyam Kumar: Haa\n',
#  'Satyam Dimri: Bhejdio\n',
#  'Satyam Dimri: Bhaii hote hi ...\n',
#  'Satyam Dimri: Pls\n',
#  'Satyam Kumar: Ok\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: bhej na observation\n',
#  'Satyam Dimri: bhejde\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Or age ka bhej\n',
#  'Satyam Dimri: Calculations ...\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: 3 15 pe ready rhio library chalenge 👍🏻\n',
#  'Satyam Dimri: Bhej bhaii jitna hogya\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: kaha se likha h ? <This message was edited>\n',
#  'Satyam Kumar: chatgpt se\n',
#  'Satyam Dimri: \U0001fae1\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Prince se bat krwa\n',
#  'Satyam Dimri: Uska no. Bhejde\n',
#  'Satyam Kumar: Prince Yadav.vcf (file attached)\n',
#  'Satyam Kumar: kal jo lt9 ke saamne se pic liye the wo bhej\n',
#  'Satyam Dimri: Padhle bhaii\n',
#  'Satyam Dimri: This message was deleted\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: 2nd me se konsa imp h?\n',
#  'Satyam Dimri: last ka qn mp h kya?\n',
#  'Satyam Kumar: 7 aur 10\n',
#  'Satyam Dimri: 2 or 3 bhi aye h pichle sal\n',
#  'Satyam Kumar: Haa wo to prove kiya hoga n copy me\n',
#  'Satyam Dimri: 10 bje tere pass aunga mai...\n',
#  'Satyam Dimri: doubts leke\n',
#  'Satyam Dimri: batadio\n',
#  'Satyam Kumar: Ok\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: oye merko t3 batadega ?\n',
#  'Satyam Dimri: Missed voice call\n',
#  'Satyam Dimri: ?\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: physics lab ki photo bhej de\n',
#  'Satyam Kumar: exp 3 ki\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: thx bro\n',
#  'Satyam Dimri: Oye barish ho rhi h aj nhi jayenge\n',
#  'Satyam Kumar: Mai lib me hu\n',
#  'Satyam Dimri: acha\n',
#  'Satyam Dimri: koini mai ab room pe hi pdh rha hu\n',
#  'Satyam Kumar: Good\n',
#  'Satyam Dimri: code with harry🙂👍🏻👌🏻\n',
#  'Satyam Kumar: Russian bhai ka no dena\n',
#  'Satyam Dimri: Russian H17-12.vcf (file attached)\n',
#  'Satyam Dimri: This message was deleted\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: phy lab file bhej jaldi\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: Thx bro\n',
#  'Satyam Kumar: Yeh bhi banana tha\n',
#  'Satyam Dimri: Tune banaya h ?\n',
#  'Satyam Kumar: No\n',
#  'Satyam Dimri: 👍🏻\n',
#  'Satyam Dimri: cp ka lab 7, 8, 9 bhejde\n',
#  'Satyam Kumar: Nhi likha hu\n',
#  'Satyam Dimri: Avinash se mang le\n',
#  'Satyam Dimri: Or photo bhejde\n',
#  'Satyam Dimri: cp ka lab 6 ka 6th ka soln behjde\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: Oye tune isme news clips nhi lagai?\n',
#  'Satyam Dimri: This message was deleted\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: This message was deleted\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: Sun!\n',
#  'Satyam Dimri: Tu konsi slides bol rha h ?\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: phy ki file krni h ?\n',
#  'Satyam Dimri: Missed voice call\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Missed voice call\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: 7491923291\n',
#  'Satyam Kumar: https://moviesmod.wiki/\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: Ye tino best h ... compare krle or dekhle tujhe konsa chaiye..\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: is format me chalega\n',
#  'Satyam Dimri: hn\n',
#  'Satyam Dimri: bhejde\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: tune to qn 6 tk kra tha na?\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: Missed voice call\n',
#  'Satyam Dimri: call utha\n',
#  'Satyam Dimri: Missed voice call\n',
#  'Satyam Kumar: Soham Ghosh.vcf (file attached)\n',
#  'Satyam Dimri: Oye kal sirf functions se hi qns puchega na ?\n',
#  'Satyam Dimri: or code bhi usi ka dega ?\n',
#  'Satyam Dimri: abe kr na boys wale grp se dlt\n',
#  'Satyam Dimri: Bhaii file ki photo bhejde...\n',
#  'Satyam Dimri: Last experiment ki ...\n',
#  'Satyam Dimri: Pls abhi likhna h  ..\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: 👍🏻\U0001faf1🏻\u200d\U0001faf2🏻\n',
#  'Satyam Dimri: oye\n',
#  'Satyam Dimri: composite fn syllabus me h? <This message was edited>\n',
#  'Satyam Kumar: Haa\n',
#  'Satyam Dimri: ok\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Iska third part ?\n',
#  'Satyam Kumar: Mera ans nhi aya hai bhej dunga baad me\n',
#  'Satyam Dimri: Ok\n',
#  'Satyam Dimri: Iska diag bhi hoga na?\n',
#  'Satyam Kumar: Diagram me female reproductive system bana le\n',
#  'Satyam Dimri: 😍ok sir\n',
#  'Satyam Dimri: abe sahi bta na diag Banega ki nhi isme ?\n',
#  'Satyam Dimri: location: https://maps.google.com/?q=24.636154174804688,77.2908935546875\n',
#  'Satyam Kumar: You deleted this message\n',
#  'Satyam Kumar: Abe kuch nhi galti se call gaya tha\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: bhaii cp ke notes bhejde loops se\n',
#  'Satyam Dimri: https://youtube.com/clip/Ugkx4V2CTf5Y_x8q_--Y_ZqshNYcIunM-ikQ?feature=shared\n',
#  'Satyam Kumar: Mai bhi to yehi sunaya tha\n',
#  'Satyam Dimri: Ye line nhi sunai thi tune ...\n',
#  'Satyam Dimri: Chal koini gana mil gya ab sunlete h 👍🏻\n',
#  'Satyam Dimri: oye sun\n',
#  'Satyam Kumar: Bol\n',
#  'Satyam Dimri: maths ke tut 8,9 ke qns bhejde\n',
#  'Satyam Dimri: bhejra h ?\n',
#  'Satyam Kumar: Abe mai room me nhi hu\n',
#  'Satyam Dimri: Samosa 9\n\nBread chop 5\n\nOmlete1\n\nChai1\n\nCoffee 1\n\nLotte Choco pie 1\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Calculation ?\n',
#  'Satyam Dimri: Precautions ?\n',
#  'Satyam Dimri: Sb bhej\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: https://9xflix.men/m/\n',
#  'Satyam Kumar: https://9xflix.men/m/panchayat-s02/\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: happi diwali\n',
#  'Satyam Dimri: Hepi diwalii🎼🎶\n',
#  'Satyam Kumar: Cp lec me proxy lagwa dena plzzzz\U0001f979\n',
#  'Satyam Kumar: Ek tuhi hai jo uske lec phone use karta hai isiliye tujhe mesaage kiya❤️\n',
#  'Satyam Dimri: Will try👍🏻\n',
#  'Satyam Dimri: Hogya\n',
#  'Satyam Dimri: 👍🏻\n',
#  'Satyam Kumar: ?\n',
#  'Satyam Dimri: Laga di\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Abhi train me hu bro\n',
#  'Satyam Dimri: Ok\n',
#  'Satyam Dimri: Kb pahunchega?\n',
#  'Satyam Kumar: Kal subah 9 baje\n',
#  'Satyam Dimri: 👍🏻\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: hvpe ka assignment bhejde jaha se tu likh rha\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Eng ka bjde baki ka\n',
#  'Satyam Kumar: Bhej n\n',
#  'Satyam Dimri: Ruk\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: On compilation and execution of a program, the\ndesired output is not obtained when certain input\nvalues are given. These types of errors which provide\nincorrect output but appears to be error-free are\ncalled\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: bhej na\n',
#  'Satyam Dimri: phrasal verb\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: Soham Ghosh.vcf (file attached)\n',
#  'Satyam Kumar: Bro paise aaj daal dega mijhe apna ticket book karna tha\n',
#  'Satyam Dimri: Maine bola to tha papa ko ..\n',
#  'Satyam Dimri: Dubar bol dunga👍🏻\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: oye phy ke tutu ka sol bhejde jo tu dikha rha tha..\n',
#  'Satyam Dimri: mere pass jo h vo alg h !!\n',
#  "Satyam Kumar: bol.'\n",
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: #include <stdio.h>\n\nint i, j;\n\n\n//<<<<<<<<matrix display>>>>>>>>>>>\nvoid cmatrix(int c[3][3]) {\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            printf("%d\\t", c[i][j]);\n        }\n        printf("\\n");\n    }\n}\n\n\n//<<<<<<<<<<<<uppertriangularmatrix>>>>>>>>>>>\nvoid uptri(int matrix[3][3]) {\n    printf("Upper Triangular Matrix:\\n");\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            if (i <= j) {\n                printf("%d\\t", matrix[i][j]);\n            } else {\n                printf("0\\t");\n            }\n        }\n        printf("\\n");\n    }\n}\n\n\n//<<<<lower triangular matrix>>>>>>>>>>>>>>>>\nvoid lowtri(int matrix[3][3]) {\n    printf("Lower Triangular Matrix:\\n");\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            if (i >= j) {\n                printf("%d\\t", matrix[i][j]);\n            } else {\n                printf("0\\t");\n            }\n        }\n        printf("\\n");\n    }\n}\n\n\n//<<<<<<<<<transpose of matrix>>>>>>>>>>>>\nvoid transpose(int matrix[3][3]) {\n    printf("Transpose of Matrix:\\n");\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            printf("%d\\t", matrix[j][i]);\n        }\n        printf("\\n");\n    }\n}\n\n\n//<<<<<<<<<check whether matrix is symmetric or not>>>>>>>>\nint isSymmetric(int matrix[3][3]) {\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            if (matrix[i][j] != matrix[j][i]) {\n                return 0;\n            }\n        }\n    }\n    return 1;\n}\n\n//<<<<<<<<sum of diagonal>>>>>>>>>>>>>>>>>>>>>>>>\n\nint sumDiagonal(int matrix[3][3]) {\n    int sum = 0;\n    for (i = 0; i < 3; i++) {\n        sum += matrix[i][i];\n    }\n    return sum;\n}\n\n\n//<<<<<<<<add two matrix>>>>>>>>>>>>>>>>>>>>>>\nvoid addmatrix(int a[3][3], int b[3][3], int c[3][3]) {\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            c[i][j] = a[i][j] + b[i][j];\n        }\n    }\n    printf("Sum of matrices:\\n");\n    cmatrix(c);\n}\n\n\n\n\n\n\n//<<<<<<<<substract two matrix>>>>>>>>>>>>>>>>>>>>>>\n\nvoid subsmatrix(int a[3][3], int b[3][3], int c[3][3]) {\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            c[i][j] = a[i][j] - b[i][j];\n        }\n    }\n    printf("Difference of matrices:\\n");\n    cmatrix(c);\n}\n\n//<<<<<<<<add two matrix>>>>>>>>>>>>>>>>>>>>>>\n\nvoid mulmatrix(int a[3][3], int b[3][3], int c[3][3]) {\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            c[i][j] = 0;\n            for (int k = 0; k < 3; k++) {\n                c[i][j] += a[i][k] * b[k][j];\n            }\n        }\n    }\n    printf("Product of matrices:\\n");\n    cmatrix(c);\n}\n\n//<< find any element in 2d matrix>>>>>>>>>>>>\n\n\nvoid search(int a[3][3],int target) {\n    int found = 0;\n    for (i = 0; i <3; i++) {\n        for (j = 0; j <3; j++) {\n            if (a[i][j] == target) {\n                printf("Element %d found at position (%d, %d)\\n", target, i + 1, j + 1);\n                found = 1;\n            }\n        }\n    }\n    if (!found) {\n        printf("Element %d not found in the matrix.\\n", target);\n    }\n}\n\n\n\n\n\n\n\n\n\n\n\n\nint main() {\n\n    int num;\n    int matrix1[3][3];\n    int matrix2[3][3];\n    int matrixr[3][3];\n\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            printf("Enter %d,%d element of matrix 1: ", i + 1, j + 1);\n            scanf("%d", &matrix1[i][j]);\n        }\n        printf("\\n");\n    }\n\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            printf("Enter %d,%d element of matrix 2: ", i + 1, j + 1);\n            scanf("%d", &matrix2[i][j]);\n        }\n        printf("\\n");\n        printf(search(matrix1))\n    }\n\n    addmatrix(matrix1, matrix2, matrixr);\n    subsmatrix(matrix1, matrix2, matrixr);\n    mulmatrix(matrix1, matrix2, matrixr);\ ...
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  "Satyam Kumar: A string in C is defined as an array of characters terminated by a null character ('\\0').but An array of characters is a collection of individual characters stored in contiguous memory locations.\n",
#  'Satyam Dimri: contiguous memory\xa0locations?\n',
#  'Satyam Kumar: array of character ko \'a\'; declare kaarenge to memory me 1 character lega but string "a" to memomry me 2 character lega ek \'a\' aur dusra \'\\0\'\n',
#  'Satyam Dimri: ok\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: han ab khul rhe\n',
#  'Satyam Dimri: baki ke bhi bhej\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Q9,q16 to 21 karle sirf\n',
#  'Satyam Dimri: Acha\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: Scrodinger ki dervation bhjde\n',
#  'Satyam Dimri: Jo tune likhi h\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: This message was deleted\n',
#  'Satyam Dimri: Tut 11 krliya ?\n',
#  'Satyam Dimri: Soln bhejde\n',
#  'Satyam Kumar: Nhi hai mere paas\n',
#  'Satyam Dimri: Tune ni kia ?\n',
#  'Satyam Kumar: Nhi\n',
#  'Satyam Dimri: Tu to bol rha tha aj krega\n',
#  'Satyam Kumar: Nhi kal karunga\n',
#  'Satyam Dimri: Avinash ne kra h ?\n',
#  'Satyam Kumar: hii\n',
#  'Satyam Dimri: Hlo\n',
#  'Satyam Dimri: bol na?\n',
#  'Satyam Dimri: hi bolke chord Diya!!\n',
#  'Satyam Kumar: Aise hi haal chaal puchna tha\n',
#  'Satyam Dimri: mere to Nilesh ne L laga diye\n',
#  'Satyam Dimri: tu bta\n',
#  'Satyam Dimri: "TOPPER"\n',
#  'Satyam Kumar: kitne aaye?\n',
#  'Satyam Dimri: F\n',
#  'Satyam Kumar: kisme??\n',
#  'Satyam Dimri: .\n',
#  'Satyam Dimri: Uski ma ki chu\n',
#  'Satyam Dimri: Mai is bar vha tha nhi to usne bhar bhar ke marks kat liye\n',
#  'Satyam Dimri: Nhi to mai bdwa leta\n',
#  'Satyam Dimri: Pichli bar bhi maine bdwa liye the\n',
#  'Satyam Kumar: kitne diye iss baar\n',
#  'Satyam Dimri: Chord na bhaii kya farq pdta h ab\n',
#  'Satyam Dimri: Ab mai usko call bhi nhi kr skta.. kya pta mai usse call kru or vo ghr pr krde\n',
#  'Satyam Dimri: Ab to suply exam hi dena pdega\n',
#  'Satyam Dimri: 😭\n',
#  'Satyam Kumar: abe to ek hi subject kaa hai n\n',
#  'Satyam Kumar: ho jaaayegaa chil\n',
#  'Satyam Kumar: btech me yeh sab hote rehtaa hai\n',
#  'Satyam Dimri: Tu to rehne de bhaii\n',
#  'Satyam Dimri: Sala sb me top krke baitha h .. or jo dost f hua hai usko chill krne bol rha😒\n',
#  'Satyam Kumar: isme bhi meri galti hai ??/\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Hn tu mujhe ache se guide nhi krta \U0001f972\n',
#  'Satyam Dimri: Agr tu mujhe pdha deta to aisa nhi hota\n',
#  'Satyam Kumar: iske liye mai aapse chama maangta hu ho sake to mujhe maaf kardena aur mai koshish karunga ki aagese mujhse aisi galti naa ho😌\n',
#  'Satyam Dimri: Bhaii nilesh ki gand me hathi ka lund 👍🏻\U0001f972\n',
#  'Satyam Dimri: 😒\n',
#  'Satyam Dimri: Mai apko shama nhi krunga\n',
#  'Satyam Dimri: Jbtk ap apni imandari ka pariram nhi dete <This message was edited>\n',
#  'Satyam Kumar: koi nhi  tujhe cp me paas karwane ka jimma mera\n',
#  'Satyam Dimri: Suply me?\n',
#  'Satyam Kumar: haa aur kismet?\n',
#  'Satyam Dimri: Mujhe lga agle sem ki bat kr rha 😒\n',
#  'Satyam Kumar: chal wo bhi\n',
#  'Satyam Dimri: \U0001fac2\n',
#  'Satyam Dimri: kya hi krlega tu ?\n',
#  'Satyam Dimri: Mujhe pta h tu kya krega...\n',
#  'Satyam Kumar: 😅kya?\n',
#  'Satyam Dimri: Tu bs mujhe bta dega ki ye pdhle\n',
#  'Satyam Dimri: But tu mujhe concept nhi smjhayega\n',
#  'Satyam Dimri: Jiska result ye hoga ki mai pass nhi hounga... jaisa is bar hua <This message was edited>\n',
#  'Satyam Kumar: koi nhi ab padha dunga\n',
#  'Satyam Dimri: 🤷🏻\u200d♂️\n',
#  'Satyam Dimri: Terse bharosa uth chuka h\n',
#  'Satyam Dimri: 😔\n',
#  'Satyam Dimri: Bhaii suply ka exam 100 marks ka hota h 😭\n',
#  'Satyam Dimri: Or isme internal ke marks bhi nhi judte\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: sare naye teachers tamanna or Mukesh ko chordke\n',
#  'Satyam Dimri: Happy new year bhaii\U0001fac2❤️\n',
#  'Satyam Kumar: Same to you brother\n',
#  'Satyam Dimri: kal a rha?\n',
#  'Satyam Kumar: 3 ko pahunch rha mai\n',
#  'Satyam Kumar: Bro class me hai?\n',
#  'Satyam Dimri: Nhi gya mai aj clg\n',
#  'Satyam Kumar: Apne batch kon kon aayaa hai?\n',
#  'Satyam Dimri: Hain?\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Train me hu aa rha hu 6 baje Tak\n',
#  'Satyam Dimri: #include<stdio.h>\nint main(){\n    int n;\n    int sum=0;\n    printf("enter n:");\n    scanf("%d",&n);\n    int arr[n];\n    for(int i=0;i<n;i++){\n        scanf("%d",&arr[i]);\n    }\n    for(int i=0;i<n;i++){\n        printf("%d",arr[i]);\n    }\n    for(int i=0;i<n;i++){\n        sum = sum+arr[i];\n    }\n    printf("%d",sum);\n    return 0;\n}\n',
#  'Satyam Dimri: ye sum ka code h .. ise pointers ke sath kaise likhu?\n',
#  'Satyam Dimri: ??\n',
#  'Satyam Kumar: #include <stdio.h>\n\nint main() {\n    int n;\n    int sum = 0;\n\n    printf("Enter n: ");\n    scanf("%d", &n);\n\n    int *arr = (int *)malloc(n * sizeof(int));\n\n    if (arr == NULL) {\n        printf("Memory allocation failed.\\n");\n        return 1;\n    }\n\n    printf("Enter %d elements:\\n", n);\n    for (int i = 0; i < n; i++) {\n        scanf("%d", arr + i);\n    }\n\n    printf("Entered elements: ");\n    for (int i = 0; i < n; i++) {\n        printf("%d ", *(arr + i));\n    }\n\n    for (int i = 0; i < n; i++) {\n        sum = sum + *(arr + i);\n    }\n\n    printf("\\nSum: %d\\n", sum);\n\n    free(arr);\n\n    return 0;\n}\n',
#  'Satyam Kumar: Dekh le jaha doubt ho puch lena\n',
#  'Satyam Dimri: ye chat gpt se kra h?\n',
#  'Satyam Kumar: Haa\n',
#  'Satyam Dimri: 🤦🏻\u200d♂️\n',
#  'Satyam Dimri: tu bta bhaii\n',
#  'Satyam Dimri: mere hi code me changes krke bta\n',
#  'Satyam Kumar: Abe laptop on karna padega ruk\n',
#  'Satyam Dimri: hn kr\n',
#  'Satyam Kumar: #include <stdio.h>\n\nint main() {\n    int n;\n    int sum = 0;\n\n    printf("Enter n: ");\n    scanf("%d", &n);\n\n    int arr[n];\n\n   \n    int *ptr = arr;\n    for (int i = 0; i < n; i++) {\n        scanf("%d", ptr + i);\n    }\n\n    // Output using pointers\n    for (int i = 0; i < n; i++) {\n        printf("%d ", *(ptr + i));\n    }\n\n    // Sum using pointers\n    for (int i = 0; i < n; i++) {\n        sum += *(ptr + i);\n    }\n\n    printf("\\nSum: %d", sum);\n\n    return 0;\n}\n',
#  'Satyam Kumar: le\n',
#  'Satyam Kumar: int *ptr = arr kaa mtlb hai arr ka first element ka address *ptr me store ho gya\n',
#  'Satyam Dimri: acha\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: Kyuki to sf me likha wo address jisme I add ho rha aur pf wala normal int hai\n',
#  'Satyam Dimri: WAP to check given word is present in a string or not iska code bataio\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: Palindrome ka code bhejde short and simple sa\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: Sarabindu Sarkar\nOther +919800392865\n',
#  'Satyam Kumar: Nhi hai\n',
#  'Satyam Dimri: Kya nhi h?\n',
#  'Satyam Kumar: Abe tu no maang rha tha n Babu Rao kaa\n',
#  'Satyam Dimri: Abe yr\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Xor\n',
#  'Satyam Dimri: oye ES ka btadega bhaii thoda basics attendance ke bad\n',
#  'Satyam Kumar: Hm\n',
#  'Satyam Dimri: 👍🏻\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: Drawing sheet le liya?\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: Last exp jo glt hua tha usko kaise krna h ?\n',
#  'Satyam Kumar: 2 page chor dena raat me bhej dunga\n',
#  'Satyam Dimri: ok\n',
#  'Satyam Dimri: phn to utha lia kr\n',
#  'Satyam Kumar: 🙄\n',
#  'Satyam Dimri: 😒\n',
#  'Satyam Dimri: prism vala likh liya pura?\n',
#  'Satyam Dimri: bhejde\n',
#  'Satyam Dimri: 1st exp ki calc bhejde\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: tu apna likh ke bhi bhej dio\n',
#  'Satyam Dimri: Sogya kya ?\n',
#  'Satyam Kumar: Haa\n',
#  'Satyam Kumar: NewJuet app  wala ka link bhej to\n',
#  'Satyam Dimri: My jp university nam h search krlw ajayega\n',
#  'Satyam Dimri: This message was deleted\n',
#  'Satyam Dimri: Bhaii oops pdhade\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Oops last din hai n\n',
#  'Satyam Dimri: Bhaii pls merko kuch nhi ata\n',
#  'Satyam Dimri: Cp jaisa hal na ho jaye mera is me bhi\n',
#  'Satyam Kumar: Abe abhi es karna hai\n',
#  'Satyam Dimri: Es hi btade fir merko\n',
#  'Satyam Dimri: Tut 3\n',
#  'Satyam Kumar: Aajna raat me\n',
#  'Satyam Dimri: Abhi ajau?\n',
#  'Satyam Kumar: Abhi Mai khud to karlu\n',
#  'Satyam Dimri: Sath me krte h\n',
#  'Satyam Kumar: \U0001fae4\n',
#  'Satyam Dimri: ??\n',
#  'Satyam Kumar: Aaaja raat me n bata dunga\n',
#  'Satyam Dimri: acha thik h bhaii rat ko aunga 9 bje\n',
#  'Satyam Kumar: Hao\n',
#  'Satyam Dimri: \U0001fae1\n',
#  'Satyam Kumar: https://open.spotify.com/playlist/0Qjefk9pIIkz6XdhwmtS9J?si=n6C46jcbRc2H6G40lifBFQ\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Abe grp pe alg soln h tu apna bhej\n',
#  'Satyam Kumar: Mera bhi same hai\n',
#  'Satyam Kumar: Abe 8 9 10nhi banaya\n',
#  'Satyam Dimri: Kyu bhaii\n',
#  'Satyam Dimri: \U0001f972\n',
#  'Satyam Dimri: 8377850312@fam\n',
#  'Satyam Dimri: 👆🏻upi id\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: tut 3 k 6,7,8,9 bhejde\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: \U0001fac2\n',
#  'Satyam Dimri: liklh lia\n?\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: tune ni likha?\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: profile credits kon dega?😂\n',
#  'Satyam Kumar: Mil jayega\n',
#  'Satyam Dimri: Us img ke corner me likhde .. clicked by satyam dimri🙃\n',
#  'Satyam Dimri: oye sun !!\n',
#  'Satyam Dimri: padding or greedy alignment kya hota h ?\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Photo bhej de\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: oye sun\n',
#  'Satyam Kumar: Bol\n',
#  'Satyam Dimri: merko oops ke topic wise questions practice krne h.. kaha se kru?\n',
#  'Satyam Kumar: Lab karle n\n',
#  'Satyam Kumar: Aur tute\n',
#  'Satyam Dimri: acha\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: https://open.spotify.com/track/4NmUWS9nRYY33CoInUlgB9?si=cJx55KD6Q9asSatmbhGV5A\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: sogya kya /\n',
#  'Satyam Dimri: *?\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: Es likh liya ?\n',
#  'Satyam Dimri: 8377850312@fam\n',
#  'Satyam Dimri: Upi id 👆🏻\n',
#  'Satyam Kumar: Bhej dia\n',
#  'Satyam Dimri: kal to 200 hi de paunga\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Bhej de bhai\n',
#  'Satyam Kumar: Tere pass Spotify ka premium hai yaa mod\n',
#  'Satyam Dimri: mod\n',
#  'Satyam Dimri: yt premium h merpe\n',
#  'Satyam Kumar: Konsa bta b\n',
#  'Satyam Dimri: hn ruk\n',
#  'Satyam Kumar: Apk share kar sakta hai?\n',
#  'Satyam Dimri: hn\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: assignment ka 5th qn kra h ?\n',
#  'Satyam Kumar: Avinash wala hi likhunga mai\n',
#  'Satyam Kumar: Abhi to nhi kiya\n',
#  'Satyam Dimri: Abe bahut bda h bhaii\n',
#  'Satyam Kumar: To\n',
#  'Satyam Dimri: Bhaii maine bhi vhi likha h .. same mt likh\n',
#  'Satyam Kumar: 🙄 mai to likhunga\n',
#  'Satyam Dimri: 🤦🏻\u200d♂️\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: Sun\n',
#  'Satyam Kumar: Bol\n',
#  'Satyam Dimri: Kitne aye ?\n',
#  'Satyam Dimri: Phy lab me\n',
#  'Satyam Kumar: 12\n',
#  'Satyam Dimri: 👍🏻\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: bol\n',
#  'Satyam Kumar: Abe Mera obs copy nhi mil rha tha\n',
#  'Satyam Dimri: obs?\n',
#  'Satyam Kumar: Physics observation copy.🙄\n',
#  'Satyam Dimri: idk\n',
#  'Satyam Kumar: Mil gya bhai\n',
#  'Satyam Dimri: gud\n',
#  'Satyam Dimri: ab jldi calc kr or bhjde\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: This message was deleted\n',
#  'Satyam Dimri
#  'Satyam Dimri: Sure, here\'s a roleplay inspired by the web series "Rocket Boys" featuring APJ Abdul Kalam, Vikram Sarabhai, Homi Bhabha, and an Englishman discussing nuclear research:\n\nSetting: A conference room in the early days of India\'s nuclear research program. APJ Abdul Kalam, Vikram Sarabhai, and Homi Bhabha are seated around a table, deep in discussion. An Englishman, representing international collaboration, joins the conversation.\n\nAPJ Abdul Kalam: (Excitedly) Gentlemen, I propose we discuss the advancements in nuclear research and its potential for India\'s future.\n\nVikram Sarabhai: (Nodding) Absolutely, Abdul. Our research in nuclear science could revolutionize various sectors, from energy to medicine.\n\nHomi Bhabha: (Thoughtfully) Indeed, the prospects are immense. Our efforts in developing nuclear technology must align with global standards and cooperation.\n\nEnglishman: (Joining the conversation) Gentlemen, allow me to introduce myself. I\'m here to discuss potential collaborations between India and international partners in nuclear research.\n\nAPJ Abdul Kalam: (Eagerly) That sounds promising! We\'re keen on expanding our knowledge base and technological capabilities through strategic collaborations.\n\nVikram Sarabhai: (Inquisitively) What specific areas of nuclear research do you think could benefit from such collaborations?\n\nEnglishman: (Explaining) We believe in sharing expertise in reactor technology, nuclear safety protocols, and waste management strategies. Collaborative efforts can accelerate progress and ensure safe implementation.\n\nHomi Bhabha: (Considering) International partnerships could indeed expedite our research goals while adhering to best practices and safety standards.\n\nAPJ Abdul Kalam: (Optimistically) Let\'s explore these opportunities further. Our collective efforts can propel India into a leading position in nuclear research and development.\n\nVikram Sarabhai: (Agreeing) Collaboration is key to unlocking the full potential of nuclear science for the benefit of humanity.\n\nEnglishman: (Concluding) I\'m glad we share a vision for collaboration and progress. Together, we can achieve great strides in nuclear research and pave the way for a brighter future.\n',
#  'Satyam Dimri: #include <iostream>\n\nclass Time {\nprivate:\n    int hours;\n    int minutes;\n\npublic:\n    // Constructor\n    *Time(int h = 0, int m = 0) : hours(h), minutes(m) {}*\n\n    // Member function to set hours and minutes\n    void setTime(int h, int m) {\n        hours = h;\n        minutes = m;\n',
#  'Satyam Dimri: ye line jo bold me likhi h vo smjha skta h ?\n',
#  'Satyam Kumar: Ise constructor kehte hai\n',
#  'Satyam Dimri: vo pta h or bta\n',
#  'Satyam Kumar: Or sab badhiya tu bata\n',
#  'Satyam Dimri: abe saale mazak mt kr bta de\n',
#  'Satyam Dimri: dekh int h or int m to initialize kr rha h .. or uske bad kya ho rha h us line me?\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: bhai doc me bhej deta\n',
#  'Satyam Dimri: or mujhe singh ki photo kyu bhej rha\n',
#  'Satyam Dimri: 😭😭\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: https://youtu.be/njxUGIk5rzY?si=XSExBfqKrJE1ZoX4\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: #include <iostream>\nusing namespace std;\nclass Student{\n    int rollno;\n    int m1,m2,m3;\n    int totmarks;\n    int getdata(){\n        cout<<"enter roll_no and marks"<<endl;\n        cin>>rollno>>m1>>m2>>m3;\n    }\n    int totmarks(){\n        total marks = m1+m2+m3;\n        return total marks;\n    }\n    }\n    \nint main() {\nstudent st[10];\nfor(int i=0;i<10;++i)\n\n    return 0;\n}\niske age kaise kru?\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: 1111\n',
#  'Satyam Dimri: 2.2+1111.5 = 14/5??\n',
#  'Satyam Dimri: copy milgyi?\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Mila?\n',
#  'Satyam Dimri: Mai gya hi nhi\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: 16mm\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: oye mai ratko aunga tere pass es ka tut krne..\n',
#  'Satyam Kumar: Ok\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: Kcl laga hai\n',
#  'Satyam Dimri: kaise ?\n',
#  'Satyam Dimri: batade yr\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: 1/s ka integrate lns hota hai\n',
#  'Satyam Dimri: Sora h kya?\n',
#  'Satyam Kumar: Haa\n',
#  'Satyam Dimri: Kb uthega ?\n',
#  'Satyam Dimri: Phy me kuch puchna tha..\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: Dy by dt v hogya\n',
#  'Satyam Dimri: *cancel\n',
#  'Satyam Kumar: Soryy\n',
#  'Satyam Dimri: Grp pe dalne vala tha .. fir socha chordo bura man jayega ..\n',
#  'Satyam Dimri: *sorry\n',
#  'Satyam Kumar: 💩\n',
#  'Satyam Dimri: Apni shakal ku bhj rha h\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: Jayega?\n',
#  'Satyam Kumar: Nhi\n',
#  'Satyam Dimri: Oop lab?\n',
#  'Satyam Kumar: Nhi aunga\n',
#  'Satyam Dimri: Ok\n',
#  'Satyam Kumar: Hii\n',
#  'Satyam Dimri: Hlo\n',
#  'Satyam Dimri: Aj attendance ke bad tut 11 krwa dega ?\n',
#  'Satyam Kumar: Aanjaio\n',
#  'Satyam Dimri: OK\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: Ln(x) ka diff 1 /x hota hau\n',
#  'Satyam Dimri: tune bola tha ki is tut me 4 formulae h ...\n',
#  'Satyam Dimri: vo 4 formulae bhej de merko\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: maths ki theory ki photo bhjde jo tune sarvagya ki copy se khichi thi..\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: Oye photo bhej\n',
#  'Satyam Kumar: Konsi\n',
#  'Satyam Dimri: Konsi kya konsi\n',
#  ...]

# %%
dates =re.findall(pattern,data)
dates
# Out:
# ['14/08/23, 1:22\u202fpm - ',
#  '14/08/23, 1:23\u202fpm - ',
#  '23/08/23, 1:12\u202fpm - ',
#  '23/08/23, 1:12\u202fpm - ',
#  '23/08/23, 1:14\u202fpm - ',
#  '27/08/23, 11:47\u202fam - ',
#  '27/08/23, 11:47\u202fam - ',
#  '27/08/23, 11:47\u202fam - ',
#  '28/08/23, 11:16\u202fpm - ',
#  '28/08/23, 11:16\u202fpm - ',
#  '28/08/23, 11:17\u202fpm - ',
#  '02/09/23, 9:37\u202fpm - ',
#  '02/09/23, 9:40\u202fpm - ',
#  '02/09/23, 11:30\u202fpm - ',
#  '02/09/23, 11:30\u202fpm - ',
#  '03/09/23, 11:45\u202fam - ',
#  '03/09/23, 11:45\u202fam - ',
#  '03/09/23, 11:48\u202fam - ',
#  '03/09/23, 11:55\u202fam - ',
#  '03/09/23, 11:55\u202fam - ',
#  '03/09/23, 11:55\u202fam - ',
#  '03/09/23, 11:55\u202fam - ',
#  '03/09/23, 11:55\u202fam - ',
#  '03/09/23, 11:55\u202fam - ',
#  '03/09/23, 11:56\u202fam - ',
#  '03/09/23, 11:56\u202fam - ',
#  '03/09/23, 11:57\u202fam - ',
#  '03/09/23, 11:57\u202fam - ',
#  '03/09/23, 11:57\u202fam - ',
#  '03/09/23, 11:57\u202fam - ',
#  '03/09/23, 11:58\u202fam - ',
#  '03/09/23, 12:00\u202fpm - ',
#  '03/09/23, 12:02\u202fpm - ',
# Out:
# ['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  'Satyam Kumar: Bro satyam here, group me add kar dena\n',
#  'Satyam Dimri: Proxy lgwa dio\n',
#  'Satyam Kumar: Ok\n',
#  'Satyam Dimri: \U0001faf1🏻\u200d\U0001faf2🏻\U0001fac2\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Kal eng lab to nhi h na ?\n',
#  'Satyam Kumar: Photo bhej dena\n',
#  'Satyam Dimri: Ok\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: Oye sun\n',
#  'Satyam Kumar: Bol\n',
#  'Satyam Dimri: Cp ka tut krlia ?\n',
#  'Satyam Kumar: Cp ka lab kar rha\n',
#  'Satyam Dimri: bhejdio krke\n',
#  'Satyam Kumar: Ok\n',
#  'Satyam Dimri: or han sun ekbat or puchni thi...\n',
#  'Satyam Kumar: ?\n',
#  'Satyam Dimri: ye alamy pe login kaise krna h ?\n',
#  'Satyam Kumar: Adamy\n',
#  'Satyam Dimri: ha vhi\n',
#  'Satyam Kumar: App download karo\n',
#  'Satyam Dimri: laptop se nhi hoga?\n',
#  'Satyam Kumar: Nope\n',
#  'Satyam Dimri: acha ruk\n',
#  'Satyam Dimri: app ka link bhej\n',
#  'Satyam Kumar: https://play.google.com/store/apps/details?id=co.acetone.acadly\n',
#  'Satyam Dimri: thx\n',
#  'Satyam Dimri: bhaii lab file bhejde cp ki\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: bhej\n',
#  'Satyam Dimri: link\n',
#  'Satyam Kumar: https://www.youtube.com/playlist?list=PLbe3v70ubrmF0UlYR-8D9BdP7dLHUhpTN\n',
#  'Satyam Dimri: kaha tk pdhna h ?\n',
#  'Satyam Dimri: starting ki 3 vids?\n',
#  'Satyam Kumar: Upto 3 lec\n',
#  'Satyam Kumar: Yaa\n',
#  'Satyam Dimri: ok\n',
#  'Satyam Kumar: https://classroom.google.com/c/NjE4NzA3MjEyMTI2/m/NTIzNTQxNDUyODcw/details\n',
#  'Satyam Dimri: https://meet.google.com/mat-nkry-eob\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: same h dono\n',
#  'Satyam Kumar: Bhag be\n',
#  'Satyam Kumar: Same kaha hai\n',
#  'Satyam Dimri: 👍🏻thx\U0001fac2\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: If else vale ka ans bta\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: bro Saturday ko chalet hai aaj man nhi kar rha utna door jaane kaa\n',
#  'Satyam Dimri: Mai bhi nhi ja rha kal jayenge\n',
#  'Satyam Kumar: physics lab2 bhej de to\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: thanks\n',
#  'Satyam Dimri: Likh ke bhej dio ..\n',
#  'Satyam Dimri: likhne ke bad bhejdio\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: https://youtube.com/@DrMukeshChandraDimriPhysics?si=t3DggRlIRCuJefnp\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: 11 bje tk likh lega tu pura ?\n',
#  'Satyam Kumar: Haa\n',
#  'Satyam Dimri: Bhejdio\n',
#  'Satyam Dimri: Bhaii hote hi ...\n',
#  'Satyam Dimri: Pls\n',
#  'Satyam Kumar: Ok\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: bhej na observation\n',
#  'Satyam Dimri: bhejde\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Or age ka bhej\n',
#  'Satyam Dimri: Calculations ...\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: 3 15 pe ready rhio library chalenge 👍🏻\n',
#  'Satyam Dimri: Bhej bhaii jitna hogya\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: kaha se likha h ? <This message was edited>\n',
#  'Satyam Kumar: chatgpt se\n',
#  'Satyam Dimri: \U0001fae1\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Prince se bat krwa\n',
#  'Satyam Dimri: Uska no. Bhejde\n',
#  'Satyam Kumar: Prince Yadav.vcf (file attached)\n',
#  'Satyam Kumar: kal jo lt9 ke saamne se pic liye the wo bhej\n',
#  'Satyam Dimri: Padhle bhaii\n',
#  'Satyam Dimri: This message was deleted\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: 2nd me se konsa imp h?\n',
#  'Satyam Dimri: last ka qn mp h kya?\n',
#  'Satyam Kumar: 7 aur 10\n',
#  'Satyam Dimri: 2 or 3 bhi aye h pichle sal\n',
#  'Satyam Kumar: Haa wo to prove kiya hoga n copy me\n',
#  'Satyam Dimri: 10 bje tere pass aunga mai...\n',
#  'Satyam Dimri: doubts leke\n',
#  'Satyam Dimri: batadio\n',
#  'Satyam Kumar: Ok\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: oye merko t3 batadega ?\n',
#  'Satyam Dimri: Missed voice call\n',
#  'Satyam Dimri: ?\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: physics lab ki photo bhej de\n',
#  'Satyam Kumar: exp 3 ki\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: thx bro\n',
#  'Satyam Dimri: Oye barish ho rhi h aj nhi jayenge\n',
#  'Satyam Kumar: Mai lib me hu\n',
#  'Satyam Dimri: acha\n',
#  'Satyam Dimri: koini mai ab room pe hi pdh rha hu\n',
#  'Satyam Kumar: Good\n',
#  'Satyam Dimri: code with harry🙂👍🏻👌🏻\n',
#  'Satyam Kumar: Russian bhai ka no dena\n',
#  'Satyam Dimri: Russian H17-12.vcf (file attached)\n',
#  'Satyam Dimri: This message was deleted\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: phy lab file bhej jaldi\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: Thx bro\n',
#  'Satyam Kumar: Yeh bhi banana tha\n',
#  'Satyam Dimri: Tune banaya h ?\n',
#  'Satyam Kumar: No\n',
#  'Satyam Dimri: 👍🏻\n',
#  'Satyam Dimri: cp ka lab 7, 8, 9 bhejde\n',
#  'Satyam Kumar: Nhi likha hu\n',
#  'Satyam Dimri: Avinash se mang le\n',
#  'Satyam Dimri: Or photo bhejde\n',
#  'Satyam Dimri: cp ka lab 6 ka 6th ka soln behjde\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: Oye tune isme news clips nhi lagai?\n',
#  'Satyam Dimri: This message was deleted\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: This message was deleted\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: Sun!\n',
#  'Satyam Dimri: Tu konsi slides bol rha h ?\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: phy ki file krni h ?\n',
#  'Satyam Dimri: Missed voice call\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Missed voice call\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: 7491923291\n',
#  'Satyam Kumar: https://moviesmod.wiki/\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: Ye tino best h ... compare krle or dekhle tujhe konsa chaiye..\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: is format me chalega\n',
#  'Satyam Dimri: hn\n',
#  'Satyam Dimri: bhejde\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: tune to qn 6 tk kra tha na?\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: Missed voice call\n',
#  'Satyam Dimri: call utha\n',
#  'Satyam Dimri: Missed voice call\n',
#  'Satyam Kumar: Soham Ghosh.vcf (file attached)\n',
#  'Satyam Dimri: Oye kal sirf functions se hi qns puchega na ?\n',
#  'Satyam Dimri: or code bhi usi ka dega ?\n',
#  'Satyam Dimri: abe kr na boys wale grp se dlt\n',
#  'Satyam Dimri: Bhaii file ki photo bhejde...\n',
#  'Satyam Dimri: Last experiment ki ...\n',
#  'Satyam Dimri: Pls abhi likhna h  ..\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: 👍🏻\U0001faf1🏻\u200d\U0001faf2🏻\n',
#  'Satyam Dimri: oye\n',
#  'Satyam Dimri: composite fn syllabus me h? <This message was edited>\n',
#  'Satyam Kumar: Haa\n',
#  'Satyam Dimri: ok\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Iska third part ?\n',
#  'Satyam Kumar: Mera ans nhi aya hai bhej dunga baad me\n',
#  'Satyam Dimri: Ok\n',
#  'Satyam Dimri: Iska diag bhi hoga na?\n',
#  'Satyam Kumar: Diagram me female reproductive system bana le\n',
#  'Satyam Dimri: 😍ok sir\n',
#  'Satyam Dimri: abe sahi bta na diag Banega ki nhi isme ?\n',
#  'Satyam Dimri: location: https://maps.google.com/?q=24.636154174804688,77.2908935546875\n',
#  'Satyam Kumar: You deleted this message\n',
#  'Satyam Kumar: Abe kuch nhi galti se call gaya tha\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: bhaii cp ke notes bhejde loops se\n',
#  'Satyam Dimri: https://youtube.com/clip/Ugkx4V2CTf5Y_x8q_--Y_ZqshNYcIunM-ikQ?feature=shared\n',
#  'Satyam Kumar: Mai bhi to yehi sunaya tha\n',
#  'Satyam Dimri: Ye line nhi sunai thi tune ...\n',
#  'Satyam Dimri: Chal koini gana mil gya ab sunlete h 👍🏻\n',
#  'Satyam Dimri: oye sun\n',
#  'Satyam Kumar: Bol\n',
#  'Satyam Dimri: maths ke tut 8,9 ke qns bhejde\n',
#  'Satyam Dimri: bhejra h ?\n',
#  'Satyam Kumar: Abe mai room me nhi hu\n',
#  'Satyam Dimri: Samosa 9\n\nBread chop 5\n\nOmlete1\n\nChai1\n\nCoffee 1\n\nLotte Choco pie 1\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Calculation ?\n',
#  'Satyam Dimri: Precautions ?\n',
#  'Satyam Dimri: Sb bhej\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: https://9xflix.men/m/\n',
#  'Satyam Kumar: https://9xflix.men/m/panchayat-s02/\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: happi diwali\n',
#  'Satyam Dimri: Hepi diwalii🎼🎶\n',
#  'Satyam Kumar: Cp lec me proxy lagwa dena plzzzz\U0001f979\n',
#  'Satyam Kumar: Ek tuhi hai jo uske lec phone use karta hai isiliye tujhe mesaage kiya❤️\n',
#  'Satyam Dimri: Will try👍🏻\n',
#  'Satyam Dimri: Hogya\n',
#  'Satyam Dimri: 👍🏻\n',
#  'Satyam Kumar: ?\n',
#  'Satyam Dimri: Laga di\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Abhi train me hu bro\n',
#  'Satyam Dimri: Ok\n',
#  'Satyam Dimri: Kb pahunchega?\n',
#  'Satyam Kumar: Kal subah 9 baje\n',
#  'Satyam Dimri: 👍🏻\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: hvpe ka assignment bhejde jaha se tu likh rha\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Eng ka bjde baki ka\n',
#  'Satyam Kumar: Bhej n\n',
#  'Satyam Dimri: Ruk\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: On compilation and execution of a program, the\ndesired output is not obtained when certain input\nvalues are given. These types of errors which provide\nincorrect output but appears to be error-free are\ncalled\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: bhej na\n',
#  'Satyam Dimri: phrasal verb\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: Soham Ghosh.vcf (file attached)\n',
#  'Satyam Kumar: Bro paise aaj daal dega mijhe apna ticket book karna tha\n',
#  'Satyam Dimri: Maine bola to tha papa ko ..\n',
#  'Satyam Dimri: Dubar bol dunga👍🏻\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: oye phy ke tutu ka sol bhejde jo tu dikha rha tha..\n',
#  'Satyam Dimri: mere pass jo h vo alg h !!\n',
#  "Satyam Kumar: bol.'\n",
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: #include <stdio.h>\n\nint i, j;\n\n\n//<<<<<<<<matrix display>>>>>>>>>>>\nvoid cmatrix(int c[3][3]) {\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            printf("%d\\t", c[i][j]);\n        }\n        printf("\\n");\n    }\n}\n\n\n//<<<<<<<<<<<<uppertriangularmatrix>>>>>>>>>>>\nvoid uptri(int matrix[3][3]) {\n    printf("Upper Triangular Matrix:\\n");\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            if (i <= j) {\n                printf("%d\\t", matrix[i][j]);\n            } else {\n                printf("0\\t");\n            }\n        }\n        printf("\\n");\n    }\n}\n\n\n//<<<<lower triangular matrix>>>>>>>>>>>>>>>>\nvoid lowtri(int matrix[3][3]) {\n    printf("Lower Triangular Matrix:\\n");\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            if (i >= j) {\n                printf("%d\\t", matrix[i][j]);\n            } else {\n                printf("0\\t");\n            }\n        }\n        printf("\\n");\n    }\n}\n\n\n//<<<<<<<<<transpose of matrix>>>>>>>>>>>>\nvoid transpose(int matrix[3][3]) {\n    printf("Transpose of Matrix:\\n");\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            printf("%d\\t", matrix[j][i]);\n        }\n        printf("\\n");\n    }\n}\n\n\n//<<<<<<<<<check whether matrix is symmetric or not>>>>>>>>\nint isSymmetric(int matrix[3][3]) {\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            if (matrix[i][j] != matrix[j][i]) {\n                return 0;\n            }\n        }\n    }\n    return 1;\n}\n\n//<<<<<<<<sum of diagonal>>>>>>>>>>>>>>>>>>>>>>>>\n\nint sumDiagonal(int matrix[3][3]) {\n    int sum = 0;\n    for (i = 0; i < 3; i++) {\n        sum += matrix[i][i];\n    }\n    return sum;\n}\n\n\n//<<<<<<<<add two matrix>>>>>>>>>>>>>>>>>>>>>>\nvoid addmatrix(int a[3][3], int b[3][3], int c[3][3]) {\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            c[i][j] = a[i][j] + b[i][j];\n        }\n    }\n    printf("Sum of matrices:\\n");\n    cmatrix(c);\n}\n\n\n\n\n\n\n//<<<<<<<<substract two matrix>>>>>>>>>>>>>>>>>>>>>>\n\nvoid subsmatrix(int a[3][3], int b[3][3], int c[3][3]) {\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            c[i][j] = a[i][j] - b[i][j];\n        }\n    }\n    printf("Difference of matrices:\\n");\n    cmatrix(c);\n}\n\n//<<<<<<<<add two matrix>>>>>>>>>>>>>>>>>>>>>>\n\nvoid mulmatrix(int a[3][3], int b[3][3], int c[3][3]) {\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            c[i][j] = 0;\n            for (int k = 0; k < 3; k++) {\n                c[i][j] += a[i][k] * b[k][j];\n            }\n        }\n    }\n    printf("Product of matrices:\\n");\n    cmatrix(c);\n}\n\n//<< find any element in 2d matrix>>>>>>>>>>>>\n\n\nvoid search(int a[3][3],int target) {\n    int found = 0;\n    for (i = 0; i <3; i++) {\n        for (j = 0; j <3; j++) {\n            if (a[i][j] == target) {\n                printf("Element %d found at position (%d, %d)\\n", target, i + 1, j + 1);\n                found = 1;\n            }\n        }\n    }\n    if (!found) {\n        printf("Element %d not found in the matrix.\\n", target);\n    }\n}\n\n\n\n\n\n\n\n\n\n\n\n\nint main() {\n\n    int num;\n    int matrix1[3][3];\n    int matrix2[3][3];\n    int matrixr[3][3];\n\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            printf("Enter %d,%d element of matrix 1: ", i + 1, j + 1);\n            scanf("%d", &matrix1[i][j]);\n        }\n        printf("\\n");\n    }\n\n    for (i = 0; i < 3; i++) {\n        for (j = 0; j < 3; j++) {\n            printf("Enter %d,%d element of matrix 2: ", i + 1, j + 1);\n            scanf("%d", &matrix2[i][j]);\n        }\n        printf("\\n");\n        printf(search(matrix1))\n    }\n\n    addmatrix(matrix1, matrix2, matrixr);\n    subsmatrix(matrix1, matrix2, matrixr);\n    mulmatrix(matrix1, matrix2, matrixr);\ ...
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  "Satyam Kumar: A string in C is defined as an array of characters terminated by a null character ('\\0').but An array of characters is a collection of individual characters stored in contiguous memory locations.\n",
#  'Satyam Dimri: contiguous memory\xa0locations?\n',
#  'Satyam Kumar: array of character ko \'a\'; declare kaarenge to memory me 1 character lega but string "a" to memomry me 2 character lega ek \'a\' aur dusra \'\\0\'\n',
#  'Satyam Dimri: ok\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: han ab khul rhe\n',
#  'Satyam Dimri: baki ke bhi bhej\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Q9,q16 to 21 karle sirf\n',
#  'Satyam Dimri: Acha\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: Scrodinger ki dervation bhjde\n',
#  'Satyam Dimri: Jo tune likhi h\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: This message was deleted\n',
#  'Satyam Dimri: Tut 11 krliya ?\n',
#  'Satyam Dimri: Soln bhejde\n',
#  'Satyam Kumar: Nhi hai mere paas\n',
#  'Satyam Dimri: Tune ni kia ?\n',
#  'Satyam Kumar: Nhi\n',
#  'Satyam Dimri: Tu to bol rha tha aj krega\n',
#  'Satyam Kumar: Nhi kal karunga\n',
#  'Satyam Dimri: Avinash ne kra h ?\n',
#  'Satyam Kumar: hii\n',
#  'Satyam Dimri: Hlo\n',
#  'Satyam Dimri: bol na?\n',
#  'Satyam Dimri: hi bolke chord Diya!!\n',
#  'Satyam Kumar: Aise hi haal chaal puchna tha\n',
#  'Satyam Dimri: mere to Nilesh ne L laga diye\n',
#  'Satyam Dimri: tu bta\n',
#  'Satyam Dimri: "TOPPER"\n',
#  'Satyam Kumar: kitne aaye?\n',
#  'Satyam Dimri: F\n',
#  'Satyam Kumar: kisme??\n',
#  'Satyam Dimri: .\n',
#  'Satyam Dimri: Uski ma ki chu\n',
#  'Satyam Dimri: Mai is bar vha tha nhi to usne bhar bhar ke marks kat liye\n',
#  'Satyam Dimri: Nhi to mai bdwa leta\n',
#  'Satyam Dimri: Pichli bar bhi maine bdwa liye the\n',
#  'Satyam Kumar: kitne diye iss baar\n',
#  'Satyam Dimri: Chord na bhaii kya farq pdta h ab\n',
#  'Satyam Dimri: Ab mai usko call bhi nhi kr skta.. kya pta mai usse call kru or vo ghr pr krde\n',
#  'Satyam Dimri: Ab to suply exam hi dena pdega\n',
#  'Satyam Dimri: 😭\n',
#  'Satyam Kumar: abe to ek hi subject kaa hai n\n',
#  'Satyam Kumar: ho jaaayegaa chil\n',
#  'Satyam Kumar: btech me yeh sab hote rehtaa hai\n',
#  'Satyam Dimri: Tu to rehne de bhaii\n',
#  'Satyam Dimri: Sala sb me top krke baitha h .. or jo dost f hua hai usko chill krne bol rha😒\n',
#  'Satyam Kumar: isme bhi meri galti hai ??/\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Hn tu mujhe ache se guide nhi krta \U0001f972\n',
#  'Satyam Dimri: Agr tu mujhe pdha deta to aisa nhi hota\n',
#  'Satyam Kumar: iske liye mai aapse chama maangta hu ho sake to mujhe maaf kardena aur mai koshish karunga ki aagese mujhse aisi galti naa ho😌\n',
#  'Satyam Dimri: Bhaii nilesh ki gand me hathi ka lund 👍🏻\U0001f972\n',
#  'Satyam Dimri: 😒\n',
#  'Satyam Dimri: Mai apko shama nhi krunga\n',
#  'Satyam Dimri: Jbtk ap apni imandari ka pariram nhi dete <This message was edited>\n',
#  'Satyam Kumar: koi nhi  tujhe cp me paas karwane ka jimma mera\n',
#  'Satyam Dimri: Suply me?\n',
#  'Satyam Kumar: haa aur kismet?\n',
#  'Satyam Dimri: Mujhe lga agle sem ki bat kr rha 😒\n',
#  'Satyam Kumar: chal wo bhi\n',
#  'Satyam Dimri: \U0001fac2\n',
#  'Satyam Dimri: kya hi krlega tu ?\n',
#  'Satyam Dimri: Mujhe pta h tu kya krega...\n',
#  'Satyam Kumar: 😅kya?\n',
#  'Satyam Dimri: Tu bs mujhe bta dega ki ye pdhle\n',
#  'Satyam Dimri: But tu mujhe concept nhi smjhayega\n',
#  'Satyam Dimri: Jiska result ye hoga ki mai pass nhi hounga... jaisa is bar hua <This message was edited>\n',
#  'Satyam Kumar: koi nhi ab padha dunga\n',
#  'Satyam Dimri: 🤷🏻\u200d♂️\n',
#  'Satyam Dimri: Terse bharosa uth chuka h\n',
#  'Satyam Dimri: 😔\n',
#  'Satyam Dimri: Bhaii suply ka exam 100 marks ka hota h 😭\n',
#  'Satyam Dimri: Or isme internal ke marks bhi nhi judte\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: sare naye teachers tamanna or Mukesh ko chordke\n',
#  'Satyam Dimri: Happy new year bhaii\U0001fac2❤️\n',
#  'Satyam Kumar: Same to you brother\n',
#  'Satyam Dimri: kal a rha?\n',
#  'Satyam Kumar: 3 ko pahunch rha mai\n',
#  'Satyam Kumar: Bro class me hai?\n',
#  'Satyam Dimri: Nhi gya mai aj clg\n',
#  'Satyam Kumar: Apne batch kon kon aayaa hai?\n',
#  'Satyam Dimri: Hain?\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Train me hu aa rha hu 6 baje Tak\n',
#  'Satyam Dimri: #include<stdio.h>\nint main(){\n    int n;\n    int sum=0;\n    printf("enter n:");\n    scanf("%d",&n);\n    int arr[n];\n    for(int i=0;i<n;i++){\n        scanf("%d",&arr[i]);\n    }\n    for(int i=0;i<n;i++){\n        printf("%d",arr[i]);\n    }\n    for(int i=0;i<n;i++){\n        sum = sum+arr[i];\n    }\n    printf("%d",sum);\n    return 0;\n}\n',
#  'Satyam Dimri: ye sum ka code h .. ise pointers ke sath kaise likhu?\n',
#  'Satyam Dimri: ??\n',
#  'Satyam Kumar: #include <stdio.h>\n\nint main() {\n    int n;\n    int sum = 0;\n\n    printf("Enter n: ");\n    scanf("%d", &n);\n\n    int *arr = (int *)malloc(n * sizeof(int));\n\n    if (arr == NULL) {\n        printf("Memory allocation failed.\\n");\n        return 1;\n    }\n\n    printf("Enter %d elements:\\n", n);\n    for (int i = 0; i < n; i++) {\n        scanf("%d", arr + i);\n    }\n\n    printf("Entered elements: ");\n    for (int i = 0; i < n; i++) {\n        printf("%d ", *(arr + i));\n    }\n\n    for (int i = 0; i < n; i++) {\n        sum = sum + *(arr + i);\n    }\n\n    printf("\\nSum: %d\\n", sum);\n\n    free(arr);\n\n    return 0;\n}\n',
#  'Satyam Kumar: Dekh le jaha doubt ho puch lena\n',
#  'Satyam Dimri: ye chat gpt se kra h?\n',
#  'Satyam Kumar: Haa\n',
#  'Satyam Dimri: 🤦🏻\u200d♂️\n',
#  'Satyam Dimri: tu bta bhaii\n',
#  'Satyam Dimri: mere hi code me changes krke bta\n',
#  'Satyam Kumar: Abe laptop on karna padega ruk\n',
#  'Satyam Dimri: hn kr\n',
#  'Satyam Kumar: #include <stdio.h>\n\nint main() {\n    int n;\n    int sum = 0;\n\n    printf("Enter n: ");\n    scanf("%d", &n);\n\n    int arr[n];\n\n   \n    int *ptr = arr;\n    for (int i = 0; i < n; i++) {\n        scanf("%d", ptr + i);\n    }\n\n    // Output using pointers\n    for (int i = 0; i < n; i++) {\n        printf("%d ", *(ptr + i));\n    }\n\n    // Sum using pointers\n    for (int i = 0; i < n; i++) {\n        sum += *(ptr + i);\n    }\n\n    printf("\\nSum: %d", sum);\n\n    return 0;\n}\n',
#  'Satyam Kumar: le\n',
#  'Satyam Kumar: int *ptr = arr kaa mtlb hai arr ka first element ka address *ptr me store ho gya\n',
#  'Satyam Dimri: acha\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: Kyuki to sf me likha wo address jisme I add ho rha aur pf wala normal int hai\n',
#  'Satyam Dimri: WAP to check given word is present in a string or not iska code bataio\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: Palindrome ka code bhejde short and simple sa\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: Sarabindu Sarkar\nOther +919800392865\n',
#  'Satyam Kumar: Nhi hai\n',
#  'Satyam Dimri: Kya nhi h?\n',
#  'Satyam Kumar: Abe tu no maang rha tha n Babu Rao kaa\n',
#  'Satyam Dimri: Abe yr\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Xor\n',
#  'Satyam Dimri: oye ES ka btadega bhaii thoda basics attendance ke bad\n',
#  'Satyam Kumar: Hm\n',
#  'Satyam Dimri: 👍🏻\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: Drawing sheet le liya?\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: Last exp jo glt hua tha usko kaise krna h ?\n',
#  'Satyam Kumar: 2 page chor dena raat me bhej dunga\n',
#  'Satyam Dimri: ok\n',
#  'Satyam Dimri: phn to utha lia kr\n',
#  'Satyam Kumar: 🙄\n',
#  'Satyam Dimri: 😒\n',
#  'Satyam Dimri: prism vala likh liya pura?\n',
#  'Satyam Dimri: bhejde\n',
#  'Satyam Dimri: 1st exp ki calc bhejde\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: tu apna likh ke bhi bhej dio\n',
#  'Satyam Dimri: Sogya kya ?\n',
#  'Satyam Kumar: Haa\n',
#  'Satyam Kumar: NewJuet app  wala ka link bhej to\n',
#  'Satyam Dimri: My jp university nam h search krlw ajayega\n',
#  'Satyam Dimri: This message was deleted\n',
#  'Satyam Dimri: Bhaii oops pdhade\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Oops last din hai n\n',
#  'Satyam Dimri: Bhaii pls merko kuch nhi ata\n',
#  'Satyam Dimri: Cp jaisa hal na ho jaye mera is me bhi\n',
#  'Satyam Kumar: Abe abhi es karna hai\n',
#  'Satyam Dimri: Es hi btade fir merko\n',
#  'Satyam Dimri: Tut 3\n',
#  'Satyam Kumar: Aajna raat me\n',
#  'Satyam Dimri: Abhi ajau?\n',
#  'Satyam Kumar: Abhi Mai khud to karlu\n',
#  'Satyam Dimri: Sath me krte h\n',
#  'Satyam Kumar: \U0001fae4\n',
#  'Satyam Dimri: ??\n',
#  'Satyam Kumar: Aaaja raat me n bata dunga\n',
#  'Satyam Dimri: acha thik h bhaii rat ko aunga 9 bje\n',
#  'Satyam Kumar: Hao\n',
#  'Satyam Dimri: \U0001fae1\n',
#  'Satyam Kumar: https://open.spotify.com/playlist/0Qjefk9pIIkz6XdhwmtS9J?si=n6C46jcbRc2H6G40lifBFQ\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Abe grp pe alg soln h tu apna bhej\n',
#  'Satyam Kumar: Mera bhi same hai\n',
#  'Satyam Kumar: Abe 8 9 10nhi banaya\n',
#  'Satyam Dimri: Kyu bhaii\n',
#  'Satyam Dimri: \U0001f972\n',
#  'Satyam Dimri: 8377850312@fam\n',
#  'Satyam Dimri: 👆🏻upi id\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: tut 3 k 6,7,8,9 bhejde\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: \U0001fac2\n',
#  'Satyam Dimri: liklh lia\n?\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: tune ni likha?\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: profile credits kon dega?😂\n',
#  'Satyam Kumar: Mil jayega\n',
#  'Satyam Dimri: Us img ke corner me likhde .. clicked by satyam dimri🙃\n',
#  'Satyam Dimri: oye sun !!\n',
#  'Satyam Dimri: padding or greedy alignment kya hota h ?\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Photo bhej de\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: oye sun\n',
#  'Satyam Kumar: Bol\n',
#  'Satyam Dimri: merko oops ke topic wise questions practice krne h.. kaha se kru?\n',
#  'Satyam Kumar: Lab karle n\n',
#  'Satyam Kumar: Aur tute\n',
#  'Satyam Dimri: acha\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: https://open.spotify.com/track/4NmUWS9nRYY33CoInUlgB9?si=cJx55KD6Q9asSatmbhGV5A\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: sogya kya /\n',
#  'Satyam Dimri: *?\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: Es likh liya ?\n',
#  'Satyam Dimri: 8377850312@fam\n',
#  'Satyam Dimri: Upi id 👆🏻\n',
#  'Satyam Kumar: Bhej dia\n',
#  'Satyam Dimri: kal to 200 hi de paunga\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Bhej de bhai\n',
#  'Satyam Kumar: Tere pass Spotify ka premium hai yaa mod\n',
#  'Satyam Dimri: mod\n',
#  'Satyam Dimri: yt premium h merpe\n',
#  'Satyam Kumar: Konsa bta b\n',
#  'Satyam Dimri: hn ruk\n',
#  'Satyam Kumar: Apk share kar sakta hai?\n',
#  'Satyam Dimri: hn\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: assignment ka 5th qn kra h ?\n',
#  'Satyam Kumar: Avinash wala hi likhunga mai\n',
#  'Satyam Kumar: Abhi to nhi kiya\n',
#  'Satyam Dimri: Abe bahut bda h bhaii\n',
#  'Satyam Kumar: To\n',
#  'Satyam Dimri: Bhaii maine bhi vhi likha h .. same mt likh\n',
#  'Satyam Kumar: 🙄 mai to likhunga\n',
#  'Satyam Dimri: 🤦🏻\u200d♂️\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: Sun\n',
#  'Satyam Kumar: Bol\n',
#  'Satyam Dimri: Kitne aye ?\n',
#  'Satyam Dimri: Phy lab me\n',
#  'Satyam Kumar: 12\n',
#  'Satyam Dimri: 👍🏻\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: bol\n',
#  'Satyam Kumar: Abe Mera obs copy nhi mil rha tha\n',
#  'Satyam Dimri: obs?\n',
#  'Satyam Kumar: Physics observation copy.🙄\n',
#  'Satyam Dimri: idk\n',
#  'Satyam Kumar: Mil gya bhai\n',
#  'Satyam Dimri: gud\n',
#  'Satyam Dimri: ab jldi calc kr or bhjde\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: This message was deleted\n',
#  'Satyam Dimri: bhj\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: Sun\n',
#  'Satyam Dimri: Ek doubt tha..\n',
#  'Satyam Dimri: Es me\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Nhi likha hu\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: 🎉 “Happy Holi! Enjoy the colors and spread joy! 🌈”\n',
#  'Satyam Dimri: होली की हार्दिक शुभकामनाऐ ❤️\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: Zinda h ?\n',
#  'Satyam Kumar: Abe baad me call karta hu abhi bahar hu\n',
#  'Satyam Dimri: call mt krio msg krio\n',
#  'Satyam Dimri: bs ek chiz puchni thi\n',
#  'Satyam Kumar: ??\n',
#  'Satyam Dimri: Good morning sir\n',
#  'Satyam Kumar: Abe sorry dekha nhi tha\n',
#  'Satyam Kumar: There is a urgent meeting at 17 ke 2 for rploleplay\n',
#  'Satyam Dimri: Time kon batayega bsdk?\n',
#  'Satyam Kumar: 9 baje bola tha chutiye\n',
#  'Satyam Kumar: Theme: "Unity in Science: Collaborating for Nuclear Progress"\n\nScene: A High-Level Summit on Nuclear Technology\n\n[The stage is set with a large conference room adorned with flags representing India, the United Kingdom, and various scientific organizations. A podium stands at the center, flanked by chairs for the distinguished guests. The backdrop features images symbolizing nuclear energy and scientific collaboration.]\n\n[As the lights dim, a hushed anticipation fills the room. The audience, comprised of scientists, diplomats, and journalists, eagerly await the arrival of the esteemed panelists.]\n\n[The curtains part, revealing APJ Abdul Kalam, Vikram Sarabhai, Homi Jehangir Bhabha, and the Englishman entering the stage to a round of applause. They take their seats at the front, ready to engage in a transformative discussion.]\n\nAPJ Abdul Kalam: (Stepping up to the podium) Ladies and gentlemen, esteemed colleagues, welcome to this historic summit on nuclear technology. Today, we gather not only as representatives of our respective nations but as stewards of scientific progress and global sustainability.\n\nVikram Sarabhai: (Addressing the audience) Our theme today is "Unity in Science: Collaborating for Nuclear Progress." In a world faced with pressing energy demands and environmental challenges, it is imperative that we come together to harness the power of nuclear technology for the betterment of humanity.\n\nHomi Jehangir Bhabha: (Emphasizing the importance of collaboration) Indeed, the challenges we face are complex and multifaceted. By pooling our expertise, resources, and innovative spirit, we can overcome these obstacles and pave the way for a brighter future.\n\nEnglishman: (Offering a perspective from the industry) As a representative of the private sector, I stand here today to reaffirm our commitment to responsible innovation and partnership. Together, we can unlock the full potential of nuclear energy while upholding the highest standards of safety, security, and sustainability.\n\n[The panelists engage in a dynamic discussion, exchanging ideas, sharing insights, and highlighting the possibilities for collaboration in nuclear research, technology development, and policy formulation.]\n\nAPJ Abdul Kalam: (Summing up the discussion) In conclusion, let us not underestimate the power of unity in science. By working together across borders, disciplines, and ideologies, we can transcend barriers and achieve remarkable feats of innovation and progress. The journey ahead will not be easy, but with determination, cooperation, and a shared vision, we can build a brighter and more sustainable future for generations to come.\n\n[As the audience rises to their feet in a standing ovation, the panelists exchange smiles and nods, knowing that they have embarked on a journey that will shape the course of nuclear technology and global development.]\n',
#  'Satyam Dimri: Sure, here\'s a roleplay inspired by the web series "Rocket Boys" featuring APJ Abdul Kalam, Vikram Sarabhai, Homi Bhabha, and an Englishman discussing nuclear research:\n\nSetting: A conference room in the early days of India\'s nuclear research program. APJ Abdul Kalam, Vikram Sarabhai, and Homi Bhabha are seated around a table, deep in discussion. An Englishman, representing international collaboration, joins the conversation.\n\nAPJ Abdul Kalam: (Excitedly) Gentlemen, I propose we discuss the advancements in nuclear research and its potential for India\'s future.\n\nVikram Sarabhai: (Nodding) Absolutely, Abdul. Our research in nuclear science could revolutionize various sectors, from energy to medicine.\n\nHomi Bhabha: (Thoughtfully) Indeed, the prospects are immense. Our efforts in developing nuclear technology must align with global standards and cooperation.\n\nEnglishman: (Joining the conversation) Gentlemen, allow me to introduce myself. I\'m here to discuss potential collaborations between India and international partners in nuclear research.\n\nAPJ Abdul Kalam: (Eagerly) That sounds promising! We\'re keen on expanding our knowledge base and technological capabilities through strategic collaborations.\n\nVikram Sarabhai: (Inquisitively) What specific areas of nuclear research do you think could benefit from such collaborations?\n\nEnglishman: (Explaining) We believe in sharing expertise in reactor technology, nuclear safety protocols, and waste management strategies. Collaborative efforts can accelerate progress and ensure safe implementation.\n\nHomi Bhabha: (Considering) International partnerships could indeed expedite our research goals while adhering to best practices and safety standards.\n\nAPJ Abdul Kalam: (Optimistically) Let\'s explore these opportunities further. Our collective efforts can propel India into a leading position in nuclear research and development.\n\nVikram Sarabhai: (Agreeing) Collaboration is key to unlocking the full potential of nuclear science for the benefit of humanity.\n\nEnglishman: (Concluding) I\'m glad we share a vision for collaboration and progress. Together, we can achieve great strides in nuclear research and pave the way for a brighter future.\n',
#  'Satyam Dimri: #include <iostream>\n\nclass Time {\nprivate:\n    int hours;\n    int minutes;\n\npublic:\n    // Constructor\n    *Time(int h = 0, int m = 0) : hours(h), minutes(m) {}*\n\n    // Member function to set hours and minutes\n    void setTime(int h, int m) {\n        hours = h;\n        minutes = m;\n',
#  'Satyam Dimri: ye line jo bold me likhi h vo smjha skta h ?\n',
#  'Satyam Kumar: Ise constructor kehte hai\n',
#  'Satyam Dimri: vo pta h or bta\n',
#  'Satyam Kumar: Or sab badhiya tu bata\n',
#  'Satyam Dimri: abe saale mazak mt kr bta de\n',
#  'Satyam Dimri: dekh int h or int m to initialize kr rha h .. or uske bad kya ho rha h us line me?\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: bhai doc me bhej deta\n',
#  'Satyam Dimri: or mujhe singh ki photo kyu bhej rha\n',
#  'Satyam Dimri: 😭😭\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: https://youtu.be/njxUGIk5rzY?si=XSExBfqKrJE1ZoX4\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: #include <iostream>\nusing namespace std;\nclass Student{\n    int rollno;\n    int m1,m2,m3;\n    int totmarks;\n    int getdata(){\n        cout<<"enter roll_no and marks"<<endl;\n        cin>>rollno>>m1>>m2>>m3;\n    }\n    int totmarks(){\n        total marks = m1+m2+m3;\n        return total marks;\n    }\n    }\n    \nint main() {\nstudent st[10];\nfor(int i=0;i<10;++i)\n\n    return 0;\n}\niske age kaise kru?\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: 1111\n',
#  'Satyam Dimri: 2.2+1111.5 = 14/5??\n',
#  'Satyam Dimri: copy milgyi?\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: Mila?\n',
#  'Satyam Dimri: Mai gya hi nhi\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: 16mm\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: oye mai ratko aunga tere pass es ka tut krne..\n',
#  'Satyam Kumar: Ok\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: Kcl laga hai\n',
#  'Satyam Dimri: kaise ?\n',
#  'Satyam Dimri: batade yr\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: 1/s ka integrate lns hota hai\n',
#  'Satyam Dimri: Sora h kya?\n',
#  'Satyam Kumar: Haa\n',
#  'Satyam Dimri: Kb uthega ?\n',
#  'Satyam Dimri: Phy me kuch puchna tha..\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: Dy by dt v hogya\n',
#  'Satyam Dimri: *cancel\n',
#  'Satyam Kumar: Soryy\n',
#  'Satyam Dimri: Grp pe dalne vala tha .. fir socha chordo bura man jayega ..\n',
#  'Satyam Dimri: *sorry\n',
#  'Satyam Kumar: 💩\n',
#  'Satyam Dimri: Apni shakal ku bhj rha h\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: Jayega?\n',
#  'Satyam Kumar: Nhi\n',
#  'Satyam Dimri: Oop lab?\n',
#  'Satyam Kumar: Nhi aunga\n',
#  'Satyam Dimri: Ok\n',
#  'Satyam Kumar: Hii\n',
#  'Satyam Dimri: Hlo\n',
#  'Satyam Dimri: Aj attendance ke bad tut 11 krwa dega ?\n',
#  'Satyam Kumar: Aanjaio\n',
#  'Satyam Dimri: OK\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Kumar: Ln(x) ka diff 1 /x hota hau\n',
#  'Satyam Dimri: tune bola tha ki is tut me 4 formulae h ...\n',
#  'Satyam Dimri: vo 4 formulae bhej de merko\n',
#  'Satyam Dimri: <Media omitted>\n',
#  'Satyam Dimri: maths ki theory ki photo bhjde jo tune sarvagya ki copy se khichi thi..\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Kumar: <Media omitted>\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: null\n',
#  'Satyam Dimri: Oye photo bhej\n',
#  'Satyam Kumar: Konsi\n',
#  'Satyam Dimri: Konsi kya konsi\n',
#  ...]

# %%
#df['message_date'] = pd.to_datetime(df['message_date'], format='%d/%m/%y, %I:%M\u202F%p - ')
df['message_date'] = pd.to_datetime(df['message_date'], format='%d/%m/%y, %I:%M %p - ')
df.rename(columns={'message_date': 'date'}, inplace=True)
dates
df.head()
# Out:
#                                         user_message                date
# 0  Messages and calls are end-to-end encrypted. N... 2023-08-14 13:22:00
# 1  Satyam Kumar: Bro satyam here, group me add ka... 2023-08-14 13:23:00
# 2                     Satyam Dimri: Proxy lgwa dio\n 2023-08-23 13:12:00
# 3                                 Satyam Kumar: Ok\n 2023-08-23 13:12:00
# 4                             Satyam Dimri: 🫱🏻‍🫲🏻🫂\n 2023-08-23 13:14:00

# %%
df.shape
# Out:
# (1178, 2)

# %%
users=[]
