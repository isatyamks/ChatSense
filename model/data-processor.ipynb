# 22/11/23, 11:27 pm - Satyam Kumar: <Media omitted>
# 23/11/23, 12:12 am - Satyam Dimri: Eng ka bjde baki ka
# 23/11/23, 9:29 am - Satyam Kumar: Bhej n
# 23/11/23, 9:29 am - Satyam Dimri: Ruk
# 23/11/23, 9:29 am - Satyam Dimri: <Media omitted>
# 23/11/23, 10:17 am - Satyam Dimri: On compilation and execution of a program, the
# desired output is not obtained when certain input
# values are given. These types of errors which provide
# incorrect output but appears to be error-free are
# called
# 23/11/23, 11:43 am - Satyam Dimri: <Media omitted>
# 23/11/23, 2:39 pm - Satyam Dimri: bhej na
# 23/11/23, 2:39 pm - Satyam Dimri: phrasal verb
# 23/11/23, 2:40 pm - Satyam Kumar: <Media omitted>
# 23/11/23, 11:18 pm - Satyam Dimri: null
# 24/11/23, 12:11 am - Satyam Kumar: <Media omitted>
# 24/11/23, 12:12 am - Satyam Kumar: <Media omitted>
# 24/11/23, 9:45 pm - Satyam Kumar: Soham Ghosh.vcf (file attached)
# 27/11/23, 11:23 am - Satyam Kumar: Bro paise aaj daal dega mijhe apna ticket book karna tha
# 27/11/23, 11:45 am - Satyam Dimri: Maine bola to tha papa ko ..
# 27/11/23, 11:45 am - Satyam Dimri: Dubar bol dunga👍🏻
# 29/11/23, 12:02 pm - Satyam Dimri: <Media omitted>
# 29/11/23, 6:08 pm - Satyam Kumar: <Media omitted>
# 01/12/23, 1:07 am - Satyam Dimri: oye phy ke tutu ka sol bhejde jo tu dikha rha tha..
# 01/12/23, 1:07 am - Satyam Dimri: mere pass jo h vo alg h !!
# 02/12/23, 11:16 pm - Satyam Kumar: bol.'
# 03/12/23, 1:02 pm - Satyam Dimri: <Media omitted>
# 03/12/23, 1:11 pm - Satyam Kumar: #include <stdio.h>
#
# int i, j;
#
#
# //<<<<<<<<matrix display>>>>>>>>>>>
# void cmatrix(int c[3][3]) {
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             printf("%d\t", c[i][j]);
#         }
#         printf("\n");
#     }
# }
#
#
# //<<<<<<<<<<<<uppertriangularmatrix>>>>>>>>>>>
# void uptri(int matrix[3][3]) {
#     printf("Upper Triangular Matrix:\n");
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             if (i <= j) {
#                 printf("%d\t", matrix[i][j]);
#             } else {
#                 printf("0\t");
#             }
#         }
#         printf("\n");
#     }
# }
#
#
# //<<<<lower triangular matrix>>>>>>>>>>>>>>>>
# void lowtri(int matrix[3][3]) {
#     printf("Lower Triangular Matrix:\n");
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             if (i >= j) {
#                 printf("%d\t", matrix[i][j]);
#             } else {
#                 printf("0\t");
#             }
#         }
#         printf("\n");
#     }
# }
#
#
# //<<<<<<<<<transpose of matrix>>>>>>>>>>>>
# void transpose(int matrix[3][3]) {
#     printf("Transpose of Matrix:\n");
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             printf("%d\t", matrix[j][i]);
#         }
#         printf("\n");
#     }
# }
#
#
# //<<<<<<<<<check whether matrix is symmetric or not>>>>>>>>
# int isSymmetric(int matrix[3][3]) {
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             if (matrix[i][j] != matrix[j][i]) {
#                 return 0;
#             }
#         }
#     }
#     return 1;
# }
#
# //<<<<<<<<sum of diagonal>>>>>>>>>>>>>>>>>>>>>>>>
#
# int sumDiagonal(int matrix[3][3]) {
#     int sum = 0;
#     for (i = 0; i < 3; i++) {
#         sum += matrix[i][i];
#     }
#     return sum;
# }
#
#
# //<<<<<<<<add two matrix>>>>>>>>>>>>>>>>>>>>>>
# void addmatrix(int a[3][3], int b[3][3], int c[3][3]) {
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             c[i][j] = a[i][j] + b[i][j];
#         }
#     }
#     printf("Sum of matrices:\n");
#     cmatrix(c);
# }
#
#
#
#
#
#
# //<<<<<<<<substract two matrix>>>>>>>>>>>>>>>>>>>>>>
#
# void subsmatrix(int a[3][3], int b[3][3], int c[3][3]) {
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             c[i][j] = a[i][j] - b[i][j];
#         }
#     }
#     printf("Difference of matrices:\n");
#     cmatrix(c);
# }
#
# //<<<<<<<<add two matrix>>>>>>>>>>>>>>>>>>>>>>
#
# void mulmatrix(int a[3][3], int b[3][3], int c[3][3]) {
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             c[i][j] = 0;
#             for (int k = 0; k < 3; k++) {
#                 c[i][j] += a[i][k] * b[k][j];
#             }
#         }
#     }
#     printf("Product of matrices:\n");
#     cmatrix(c);
# }
#
# //<< find any element in 2d matrix>>>>>>>>>>>>
#
#
# void search(int a[3][3],int target) {
#     int found = 0;
#     for (i = 0; i <3; i++) {
#         for (j = 0; j <3; j++) {
#             if (a[i][j] == target) {
#                 printf("Element %d found at position (%d, %d)\n", target, i + 1, j + 1);
#                 found = 1;
#             }
#         }
#     }
#     if (!found) {
#         printf("Element %d not found in the matrix.\n", target);
#     }
# }
#
#
#
#
#
#
#
#
#
#
#
#
# int main() {
#
#     int num;
#     int matrix1[3][3];
#     int matrix2[3][3];
#     int matrixr[3][3];
#
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             printf("Enter %d,%d element of matrix 1: ", i + 1, j + 1);
#             scanf("%d", &matrix1[i][j]);
#         }
#         printf("\n");
#     }
#
#     for (i = 0; i < 3; i++) {
#         for (j = 0; j < 3; j++) {
#             printf("Enter %d,%d element of matrix 2: ", i + 1, j + 1);
#             scanf("%d", &matrix2[i][j]);
#         }
#         printf("\n");
#         printf(search(matrix1))
#     }
#
#     addmatrix(matrix1, matrix2, matrixr);
#     subsmatrix(matrix1, matrix2, matrixr);
#     mulmatrix(matrix1, matrix2, matrixr);
#
#     uptri(matrix1);
#     lowtri(matrix2);
#     transpose(matrix1);
#
#     int diagonalSum = sumDiagonal(matrix1);
#     printf("\nSum of diagonal elements of matrix A: %d\n", diagonalSum);
#
#     if (isSymmetric(matrix1)) {
#         printf("\nMatrix A is symmetric.\n");
#     } else {
#         printf("\nMatrix A is not symmetric.\n");
#     }
#
#     printf("Enter the target: ");
#
#
#     scanf("%d",&num);
#
#
#
#     search(matrix1,num);
#
#     return 0;
# }
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 6:30 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:05 pm - Satyam Kumar: A string in C is defined as an array of characters terminated by a null character ('\0').but An array of characters is a collection of individual characters stored in contiguous memory locations.
# 03/12/23, 11:07 pm - Satyam Dimri: contiguous memory locations?
# 03/12/23, 11:08 pm - Satyam Kumar: array of character ko 'a'; declare kaarenge to memory me 1 character lega but string "a" to memomry me 2 character lega ek 'a' aur dusra '\0'
# 03/12/23, 11:08 pm - Satyam Dimri: ok
# 03/12/23, 11:14 pm - Satyam Dimri: null
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11:18 pm - Satyam Kumar: <Media omitted>
# 03/12/23, 11
# 03/01/24, 2:53 pm - Satyam Kumar: Bro class me hai?
# 03/01/24, 2:59 pm - Satyam Dimri: Nhi gya mai aj clg
# 03/01/24, 2:59 pm - Satyam Kumar: Apne batch kon kon aayaa hai?
# 03/01/24, 4:13 pm - Satyam Dimri: Hain?
# 03/01/24, 4:13 pm - Satyam Dimri: null
# 03/01/24, 4:14 pm - Satyam Kumar: Train me hu aa rha hu 6 baje Tak
# 03/01/24, 6:19 pm - Satyam Dimri: #include<stdio.h>
# int main(){
#     int n;
#     int sum=0;
#     printf("enter n:");
#     scanf("%d",&n);
#     int arr[n];
#     for(int i=0;i<n;i++){
#         scanf("%d",&arr[i]);
#     }
#     for(int i=0;i<n;i++){
#         printf("%d",arr[i]);
#     }
#     for(int i=0;i<n;i++){
#         sum = sum+arr[i];
#     }
#     printf("%d",sum);
#     return 0;
# }
# 03/01/24, 6:19 pm - Satyam Dimri: ye sum ka code h .. ise pointers ke sath kaise likhu?
# 03/01/24, 6:21 pm - Satyam Dimri: ??
# 03/01/24, 6:22 pm - Satyam Kumar: #include <stdio.h>
#
# int main() {
#     int n;
#     int sum = 0;
#
#     printf("Enter n: ");
#     scanf("%d", &n);
#
#     int *arr = (int *)malloc(n * sizeof(int));
#
#     if (arr == NULL) {
#         printf("Memory allocation failed.\n");
#         return 1;
#     }
#
#     printf("Enter %d elements:\n", n);
#     for (int i = 0; i < n; i++) {
#         scanf("%d", arr + i);
#     }
#
#     printf("Entered elements: ");
#     for (int i = 0; i < n; i++) {
#         printf("%d ", *(arr + i));
#     }
#
#     for (int i = 0; i < n; i++) {
#         sum = sum + *(arr + i);
#     }
#
#     printf("\nSum: %d\n", sum);
#
#     free(arr);
#
#     return 0;
# }
# 03/01/24, 6:22 pm - Satyam Kumar: Dekh le jaha doubt ho puch lena
# 03/01/24, 6:22 pm - Satyam Dimri: ye chat gpt se kra h?
# 03/01/24, 6:22 pm - Satyam Kumar: Haa
# 03/01/24, 6:23 pm - Satyam Dimri: 🤦🏻‍♂️
# 03/01/24, 6:23 pm - Satyam Dimri: tu bta bhaii
# 03/01/24, 6:23 pm - Satyam Dimri: mere hi code me changes krke bta
# 03/01/24, 6:23 pm - Satyam Kumar: Abe laptop on karna padega ruk
# 03/01/24, 6:23 pm - Satyam Dimri: hn kr
# 03/01/24, 6:25 pm - Satyam Kumar: #include <stdio.h>
#
# int main() {
#     int n;
#     int sum = 0;
#
#     printf("Enter n: ");
#     scanf("%d", &n);
#
#     int arr[n];
#
#
#     int *ptr = arr;
#     for (int i = 0; i < n; i++) {
#         scanf("%d", ptr + i);
#     }
#
#     // Output using pointers
#     for (int i = 0; i < n; i++) {
#         printf("%d ", *(ptr + i));
#     }
#
#     // Sum using pointers
#     for (int i = 0; i < n; i++) {
#         sum += *(ptr + i);
#     }
#
#     printf("\nSum: %d", sum);
#
#     return 0;
# }
# 03/01/24, 6:25 pm - Satyam Kumar: le
# 03/01/24, 6:26 pm - Satyam Kumar: int *ptr = arr kaa mtlb hai arr ka first element ka address *ptr me store ho gya
# 03/01/24, 6:28 pm - Satyam Dimri: acha
# 09/05/24, 10:39 pm - Satyam Dimri: a rha hu tere pass
# 09/05/24, 10:56 pm - Satyam Kumar: #include <iostream>
# #include <fstream>
# using namespace std;
# int d=0;
# int main()
# {
#     bool cond = true;
#     do
#     {
#         cout << "Welcome to file encryption system:\n";
#         cout << "1. Display source file\n";
#         cout << "2. Encrypt source file \n";
#         cout << "3. Decrypt source file\n";
#         cout << "4. Quit\n";
#         int input;
#         cin>> input;
#         switch(input)
#         {
#             case 1:
#             {
#                 if(d!=1)
#                 {
#                     ofstream fout;
#                     fout.open("source.txt");
#                     if(!fout.good())
#                     {
#                         cout<<"Error in opening file"<<endl;
#                         return 1;
#                     }
#                     cout<<"Enter the text to write in file: "<<endl;
#                     cout<<"Enter -1 to stop"<<endl;
#                     string line;
#                     while(getline(cin,line) && line != "-1")
#                     {
#                         fout << line << endl;
#                     }
#
#                     fout.close();
#                     d=1;
#                 }
#                 ifstream fin;
#                 fin.open("source.txt");
#                 if(!fin.good())
#                 {
#                     cout<<"Error in opening file"<<endl;
#                     return 1;
#                 }
#
#                 cout<<"The content of source file is: "<<endl;
#                 string line1;
#                 while(getline(fin,line1))
#                 {
#                     cout<<line1<<endl;
#                 }
#                 fin.close();
#                 break;
#             }
#
#             case 2:
#             {
#                 ifstream fin("source.txt");
#                 if(!fin.good())
#                 {
#                     cout<<"Error in opening file"<<endl;
#                     return 1;
#                 }
#                 int key;
#                 cout<<"Enter key value to encrypt the file: ";
#                 cin>>key;
#                 ofstream fout;
#                 fout.open("encrypt.txt");
#                 if(!fout.good())
#                 {
#                     cout<<"Error in opening file"<<endl;
#                     return 1;
#                 }
#                 char ch;
#                 while(fin.get(ch))
#                 {
#                     ch += key;
#                     fout<<ch;
#                 }
#                 cout<<"File encrypted successfully"<<endl;
#                 fin.close();
#                 fout.close();
#                 break;
#             }
#
#             case 3:
#             {
#                 ifstream fin("encrypt.txt");
#                 if(!fin.good())
#                 {
#                     cout<<"Error in opening file"<<endl;
#                     return 1;
#                 }
#
#                 int key;
#                 cout<<"Enter key value to decrypt the file: ";
#                 cin>>key;
#
#                 ofstream fout("decrypt.txt");
#                 if(!fout.good())
#                 {
#                     cout<<"Error in opening file"<<endl;
#                     return 1;
#                 }
#
#                 char ch;
#                 while(fin.get(ch))
#                 {
#                     ch -= key;
#                     fout<<ch;
#                 }
#                 cout<<"File decrypted successfully"<<endl;
#                 fin.close();
#                 fout.close();
#                 break;
#
#             }
#
#             case 4:
#             {
#                 cout<<"Thank you for using file encryption system"<<endl;
#                 cond = false;
#                 break;
#             }
#
#             default:
#             {
#                 cout<<"Invalid input"<<endl;
#             }
#         }
#     } while (cond);
#
#     return 0;
# }
# 09/05/24, 10:58 pm - Satyam Kumar: #include <iostream>
# #include <fstream>
# using namespace std;
#
# int main()
# {
#     ofstream fout("test.txt");
#     ofstream fout1("test1.txt");
#     if(!fout.good())
#     {
#         cout<<"Error in creating file"<<endl;
#         return 1;
#     }
#     if(!fout1.good())
#     {
#         cout<<"Error in creating file"<<endl;
#         return 1;
#     }
#
#     fout<<1<<endl;
#     fout<<2<<endl;
#     fout<<3<<endl;
#     fout<<4<<endl;
#
#     fout1<<7<<endl;
#     fout1<<8<<endl;
#     fout1<<9<<endl;
#     fout1<<10<<endl;
#
#     fout.close();
#     fout1.close();
#
#     ifstream fin("test.txt");
#     ifstream fin1("test1.txt");
#     if(!fin.good())
#     {
#         cout<<"Error in opening file"<<endl;
#         return 1;
#     }
#     if(!fin1.good())
#     {
#         cout<<"Error in opening file"<<endl;
#         return 1;
#     }
#
#     ofstream out_file("Result.txt");
#     if(!out_file.good())
#     {
#         cout<<"Error in creating file"<<endl;
#         return 1;
#     }
#
#     int a;
#     int b;
#     fin>>a;
#     fin1>>b;
#
#     while(fin || fin1)
#     {
#         if(!fin)
#         {
#             out_file<<b<<endl;
#             fin1>>b;
#             continue;
#         }
#         else if(!fin1)
#         {
#             out_file<<a<<endl;
#             fin>>a;
#             continue;
#         }
#         if(a<b)
#         {
#             out_file<<a<<endl;
#             while(fin>>a && a<b)
#             {
#                 out_file<<a<<endl;
#             }
#         }
#         else if(b<a)
#         {
#             out_file<<b<<endl;
#             while(fin1>>b && b<a)
#             {
#                 out_file<<b<<endl;
#             }
#         }
#         else if(a==b)
#         {
#             out_file<<a<<endl<<b<<endl;
#         }
#
#     }
#
#     fin.close();
#     fin1.close();
#     out_file.close();
#
#     return 0;
# }
# 09/05/24, 11:02 pm - Satyam Dimri: 5 <This message was edited>
# 09/05/24, 11:03 pm - Satyam Kumar: #include <iostream>
# #include <fstream>
#
# using namespace std;
#
# int main()
# {
#     ofstream fin;
#     ofstream fin1;
#     fin.open("TEXT2.txt");
#     fin1.open("TEXT.txt");
#     if(!fin.good())
#     {
#         cout<<"Error in opening file"<<endl;
#         return 1;
#     }
#
#     if(!fin1.good())
#     {
#         cout<<"Error in opening file"<<endl;
#         return 1;
#     }
#
#     cout<<"Enter the text to write in file: "<<endl;
#     cout<<"Enter -1 to stop"<<endl;
#     string line;
#     while(getline(cin,line) && line != "-1")
#     {
#         fin << line << endl;
#     }
#
#     fin.close();
#
#     ifstream fout("TEXT2.txt");
#     if(!fout.good())
#     {
#         cout<<"Error in opening file"<<endl;
#         return 1;
#     }
#     cout<<"Copying the content of TEXT2.txt to TEXT.txt"<<endl;
#     string line1;
#     while(getline(fout,line1))
#     {
#         fin1 << line1 << endl;
#     }
#
#     fin1.close();
#     fout.close();
#     return 0;
#
#
# }
# 09/05/24, 11:03 pm - Satyam Dimri: 3
# 09/05/24, 11:03 pm - Satyam Kumar: #include <iostream>
# #include <fstream>
#
# using namespace std;
#
# int main()
# {
#     ofstream fout1("file1.txt");
#     if(!fout1.good())
#     {
#         cout<<"Error in opening file1"<<endl;
#     }
#
#     ofstream fout2("file2.txt");
#     if(!fout2.good())
#     {
#         cout<<"Error in opening file2"<<endl;
#     }
#
#     fout1<<"hi my name is ";
#     fout2<<"Avinash Sharma";
#
#     fout1.close();
#     fout2.close();
#
#     ofstream fout3("merge_file.txt");
#     if(!fout3.good())
#     {
#         cout<<"Error in opening merge_file"<<endl;
#         return 1;
#     }
#
#     ifstream fin1("file1.txt");
#     ifstream fin2("file2.txt");
#
#     string line;
#     if(fin1.good())
#     {
#         while(getline(fin1, line))
#         {
#             fout3 << line;
#         }
#     }
#     if(fin2.good())
#     {
#         while(getline(fin2, line))
#         {
#             fout3 << line ;
#         }
#     }
#
#     fin1.close();
#     fin2.close();
#     fout3.close();
#
#     return 0;
# }
# 09/05/24, 11:04 pm - Satyam Dimri: 4
# 09/05/24, 11:21 pm - Satyam Kumar: <Media omitted>
# 09/05/24, 11:21 pm - Satyam Kumar: <Media omitted>
# 09/05/24, 11:22 pm - Satyam Kumar: <Media omitted>
# 10/05/24, 7:02 pm - Satyam Dimri: null
# 10/05/24, 10:37 pm - Satyam Dimri: null
# 10/05/24, 11:28 pm - Satyam Dimri: null
# 11/05/24, 10:03 am - Satyam Dimri: null
# 11/05/24, 10:03 am - Satyam Dimri: null
# 11/05/24, 10:04 am - Satyam Dimri: null
# 11/05/24, 6:56 pm - Satyam Dimri: null
# 11/05/24, 6:57 pm - Satyam Kumar: Lib me hu abhi
# 11/05/24, 6:57 pm - Satyam Kumar: Kya hua bol
# 11/05/24, 11:06 pm - Satyam Dimri: null
# 11/05/24, 11:11 pm - Satyam Dimri: null
# 11/05/24, 11:49 pm - Satyam Dimri: null
# 12/05/24, 2:05 am - Satyam Dimri: Sogya kya (
# 12/05/24, 2:05 am - Satyam Dimri: *?
# 12/05/24, 2:06 am - Satyam Kumar: Haan
# 12/05/24, 2:06 am - Satyam Dimri: Sahi me kya ? Ek doubt tha yr..
# 12/05/24, 2:06 am - Satyam Kumar: Kya
# 12/05/24, 2:06 am - Satyam Dimri: Tut 11 me jo 8th qn h ...
# 12/05/24, 2:07 am - Satyam Dimri: Usme diodes ko open kyu kra h ?
# 12/05/24, 2:07 am - Satyam Kumar: Abe dekh lena reversed hias hoga
# 12/05/24, 2:10 am - Satyam Dimri: But pta nhi current kidhr se a rha ...
# 12/05/24, 2:10 am - Satyam Dimri: Tu sahi me so gya kya ??
# 12/05/24, 2:10 am - Satyam Dimri: Call lgau ya kal hi puchu?
# 12/05/24, 2:10 am - Satyam Kumar: Kal hi puchna
# 12/05/24, 2:17 am - Satyam Dimri: Good night
# 12/05/24, 10:25 am - Satyam Dimri: apne spotify ka apk send krde
# 12/05/24, 11:57 am - Satyam Dimri: ?
# 12/05/24, 12:08 pm - Satyam Kumar: <Media omitted>
# 13/05/24, 12:22 am - Satyam Kumar: <Media omitted>
# 13/05/24, 8:23 am - Satyam Dimri: abe vo bhejio jo tune badi sheet pe likha tha
# 14/05/24, 9:27 am - Satyam Dimri: <Media omitted>
# 14/05/24, 9:27 am - Satyam Dimri: <Media omitted>
# 14/05/24, 12:10 pm - Satyam Kumar: <Media omitted>
# 14/05/24, 11:37 pm - Satyam Kumar: <Media omitted>
# 14/05/24, 11:37 pm - Satyam Kumar: <Media omitted>
# 15/05/24, 7:01 am - Satyam Dimri: <Media omitted>
# 15/05/24, 9:13 am - Satyam Kumar: <Media omitted>
# 15/05/24, 9:26 am - Satyam Dimri: bhai ajau kya odhne?
# 15/05/24, 9:26 am - Satyam Dimri: *pdhne
# 15/05/24, 9:27 am - Satyam Kumar: Nhha
# 15/05/24, 9:28 am - Satyam Dimri: fir kb ?
# 15/05/24, 9:28 am - Satyam Dimri: bhai kuch nhi ata merko pls pdhade
# 15/05/24, 9:28 am - Satyam Kumar: Aaja yrr
# 15/05/24, 9:28 am - Satyam Dimri: ara hu
# 15/05/24, 8:47 pm - Satyam Dimri: <Media omitted>
# 15/05/24, 8:47 pm - Satyam Dimri: <Media omitted>
# 15/05/24, 8:47 pm - Satyam Dimri: <Media omitted>
# 15/05/24, 8:47 pm - Satyam Dimri: <Media omitted>
# 15/05/24, 8:47 pm - Satyam Dimri: <Media omitted>
# 15/05/24, 8:47 pm - Satyam Dimri: <Media omitted>
# 15/05/24,